# %%
import sys
sys.path.append("/home/yixiuz/md4")

# %%
from md4.configs.md4.text8 import get_config
from collections.abc import Callable, Mapping, Sequence
import copy
import functools
from typing import Any

from absl import logging
from clu import metric_writers
from clu import metrics
from clu import parameter_overview
from clu import periodic_actions
from etils import epath
import flax
import flax.jax_utils as flax_utils
import flax.linen as nn
import grain.python as graåçin
import jax
from jax.experimental import checkify
import jax.numpy as jnp
import ml_collections
import numpy as np
import optax
from orbax import checkpoint as orbax_checkpoint

from md4 import input_pipeline
from md4 import input_pipeline_v2
from md4 import sampling
from md4 import utils
from md4.models import utils as model_utils

from md4.train import *
from md4.train import _get_checkpoint_manager

import pickle
from tqdm import tqdm

config = get_config()
# workdir = "/root/md4/expt_contantlr_deeper__model_untie"

from clu import parameter_overview

# %% [markdown]
# # Load checkpoint

# %%
# workdir = "gs://maskdiff/SIC/text8_sic_time_weighted"
# workdir = "gs://maskdiff/SIC/text8_sic_fixed"
workdir = "gs://maskdiff/SIC/text8_sic_fixed_32_steps"

# %%
with open(config.vocab_dir, "rb") as f:
    vocab = pickle.load(f)

workdir = epath.Path(workdir)
workdir.mkdir(parents=True, exist_ok=True)

rng = utils.get_rng(config.seed)
logging.info("Using random seed %s.", rng)
writer = metric_writers.create_default_writer(
    workdir, just_logging=jax.process_index() > 0
)

# Learning rate schedule.
assert config.batch_size % jax.device_count() == 0
per_device_batch_size = config.batch_size // jax.device_count()
num_train_steps = input_pipeline.get_num_train_steps(config)
steps_per_epoch = num_train_steps // config.num_epochs
logging.info(
    "num_train_steps=%d, steps_per_epoch=%d", num_train_steps, steps_per_epoch
)

schedule_fn = functools.partial(
    get_learning_rate,
    base_learning_rate=config.learning_rate,
    num_steps=num_train_steps,
    warmup_steps=config.warmup_steps,
    schedule_type=config.learning_rate_schedule,
)

# Build input pipeline.
rng, data_seed = jax.random.split(rng)
data_seed = int(
    jax.random.randint(data_seed, [], minval=0, maxval=np.iinfo(np.int32).max)
)
# The input pipeline runs on each process and loads data for local TPUs.
create_datasets = (
    input_pipeline_v2.create_datasets
    if config.get("use_v2_input_pipeline", None)
    else input_pipeline.create_datasets
)
train_loader, eval_loaders, dataset_info = create_datasets(config, data_seed)
train_iter = iter(train_loader)
# Initialize model.
rng, model_rng = jax.random.split(rng)
data_shape = input_pipeline.get_data_shape(config)
# Note: parameters are initialized in half precision if mixed_precision_training=True
# We could also try casting them to half precision here
model, optimizer, train_state, metrics_class = (
    create_train_state(  # pylint: disable=invalid-name
        config,
        model_rng,
        input_shape=(per_device_batch_size // config.num_microbatches,)
        + data_shape,
        schedule_fn=schedule_fn,
    )
)
# # Set up checkpointing of the model and the input pipeline.
# checkpoint_manager = _get_checkpoint_manager(config, workdir)
# # Retrieve data from previous checkpoints if possible.
checkpointed_state = dict(train_state=train_state, 
    step=0
    # train_iter=train_iter
)

from clu import checkpoint
checkpoint_dir = str(workdir / "checkpoints")
# The vdm code initalizes two checkpoints, one for loading and one for saving
# which I don't understand
# ckpt = checkpoint.MultihostCheckpoint(checkpoint_dir)
ckpt = checkpoint.Checkpoint(checkpoint_dir, max_to_keep=10)
checkpoint_to_restore = ckpt.get_latest_checkpoint_to_restore_from()

if checkpoint_to_restore:
    checkpointed_state = ckpt.restore_or_initialize(checkpointed_state)
# state_restore_dict = ckpt.restore_dict(checkpoint_to_restore)
# checkpointed_state = restore_partial(checkpointed_state, state_restore_dict)
train_state = checkpointed_state["train_state"]

# %%
# train_state.params
# Count the number of parameters
def count_parameters(params):
  total = 0
  for param in jax.tree_util.tree_leaves(params):
    total += param.size
  return total
    
num_params = count_parameters(flax_utils.unreplicate(train_state.params))
print("Number of parameters: ", num_params)
# Out:
# Number of parameters:  153259

# %%
overview = parameter_overview.get_parameter_overview(flax_utils.unreplicate(train_state.params))
print(overview)
# Out:
# +---------------------------------------------------------------------+---------+---------+-------+-----------+---------+
# | Name                                                                | Shape   | Dtype   | Size  | Mean      | Std     |
# +---------------------------------------------------------------------+---------+---------+-------+-----------+---------+
# | classifier/CondEmbedding_0/Dense_0/bias                             | ()      | float32 | 1     | -0.415    | 0.0     |
# | classifier/CondEmbedding_0/Dense_0/kernel                           | (64,)   | float32 | 64    | -0.12     | 0.117   |
# | classifier/CondEmbedding_0/dense0/bias                              | ()      | float32 | 1     | -0.0326   | 0.0     |
# | classifier/CondEmbedding_0/dense0/kernel                            | (256,)  | float32 | 256   | -0.0104   | 0.152   |
# | classifier/Embed_0/embedding                                        | (64,)   | float32 | 64    | -0.000509 | 0.0453  |
# | classifier/Transformer_0/Dense_0/bias                               | ()      | float32 | 1     | -0.00599  | 0.0     |
# | classifier/Transformer_0/Dense_0/kernel                             | (768,)  | float32 | 768   | 0.0011    | 0.153   |
# | classifier/Transformer_0/Dense_1/bias                               | ()      | float32 | 1     | 0.00359   | 0.0     |
# | classifier/Transformer_0/Dense_1/kernel                             | (1536,) | float32 | 1,536 | -0.0673   | 0.211   |
# | classifier/Transformer_0/Dense_2/kernel                             | (27,)   | float32 | 27    | -0.0174   | 0.101   |
# | classifier/Transformer_0/TransformerBlock_0/Dense_0/bias            | ()      | float32 | 1     | -0.00226  | 0.0     |
# | classifier/Transformer_0/TransformerBlock_0/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0716   | 0.142   |
# | classifier/Transformer_0/TransformerBlock_0/attention/wk/kernel     | (768,)  | float32 | 768   | 0.000791  | 0.11    |
# | classifier/Transformer_0/TransformerBlock_0/attention/wo/kernel     | (768,)  | float32 | 768   | -0.00319  | 0.114   |
# | classifier/Transformer_0/TransformerBlock_0/attention/wq/kernel     | (768,)  | float32 | 768   | 0.0037    | 0.104   |
# | classifier/Transformer_0/TransformerBlock_0/attention/wv/kernel     | (768,)  | float32 | 768   | 0.000744  | 0.0481  |
# | classifier/Transformer_0/TransformerBlock_0/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | 0.0774    | 0.0992  |
# | classifier/Transformer_0/TransformerBlock_0/feed_forward/w2/kernel  | (768,)  | float32 | 768   | 0.000116  | 0.00902 |
# | classifier/Transformer_0/TransformerBlock_0/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | -0.000637 | 0.0229  |
# | classifier/Transformer_0/TransformerBlock_1/Dense_0/bias            | ()      | float32 | 1     | -0.000578 | 0.0     |
# | classifier/Transformer_0/TransformerBlock_1/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0446   | 0.204   |
# | classifier/Transformer_0/TransformerBlock_1/attention/wk/kernel     | (768,)  | float32 | 768   | 0.0025    | 0.131   |
# | classifier/Transformer_0/TransformerBlock_1/attention/wo/kernel     | (768,)  | float32 | 768   | -0.00381  | 0.116   |
# | classifier/Transformer_0/TransformerBlock_1/attention/wq/kernel     | (768,)  | float32 | 768   | 0.00578   | 0.108   |
# | classifier/Transformer_0/TransformerBlock_1/attention/wv/kernel     | (768,)  | float32 | 768   | -0.00167  | 0.0599  |
# | classifier/Transformer_0/TransformerBlock_1/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | 0.0186    | 0.0465  |
# | classifier/Transformer_0/TransformerBlock_1/feed_forward/w2/kernel  | (768,)  | float32 | 768   | -0.000271 | 0.0879  |
# | classifier/Transformer_0/TransformerBlock_1/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | -0.000494 | 0.0379  |
# | classifier/Transformer_0/TransformerBlock_10/Dense_0/bias           | ()      | float32 | 1     | 0.00825   | 0.0     |
# | classifier/Transformer_0/TransformerBlock_10/Dense_0/kernel         | (4608,) | float32 | 4,608 | -0.0258   | 0.313   |
# | classifier/Transformer_0/TransformerBlock_10/attention/wk/kernel    | (768,)  | float32 | 768   | -0.00668  | 0.157   |
# | classifier/Transformer_0/TransformerBlock_10/attention/wo/kernel    | (768,)  | float32 | 768   | -0.00142  | 0.198   |
# | classifier/Transformer_0/TransformerBlock_10/attention/wq/kernel    | (768,)  | float32 | 768   | -0.00128  | 0.153   |
# | classifier/Transformer_0/TransformerBlock_10/attention/wv/kernel    | (768,)  | float32 | 768   | -0.00747  | 0.199   |
# | classifier/Transformer_0/TransformerBlock_10/feed_forward/w1/kernel | (2048,) | float32 | 2,048 | 0.025     | 0.162   |
# | classifier/Transformer_0/TransformerBlock_10/feed_forward/w2/kernel | (768,)  | float32 | 768   | 0.0133    | 0.194   |
# | classifier/Transformer_0/TransformerBlock_10/feed_forward/w3/kernel | (2048,) | float32 | 2,048 | 0.000777  | 0.201   |
# | classifier/Transformer_0/TransformerBlock_11/Dense_0/bias           | ()      | float32 | 1     | -0.00477  | 0.0     |
# | classifier/Transformer_0/TransformerBlock_11/Dense_0/kernel         | (4608,) | float32 | 4,608 | -0.0359   | 0.302   |
# | classifier/Transformer_0/TransformerBlock_11/attention/wk/kernel    | (768,)  | float32 | 768   | 0.00597   | 0.141   |
# | classifier/Transformer_0/TransformerBlock_11/attention/wo/kernel    | (768,)  | float32 | 768   | 0.00936   | 0.242   |
# | classifier/Transformer_0/TransformerBlock_11/attention/wq/kernel    | (768,)  | float32 | 768   | 0.00215   | 0.145   |
# | classifier/Transformer_0/TransformerBlock_11/attention/wv/kernel    | (768,)  | float32 | 768   | -0.0018   | 0.213   |
# | classifier/Transformer_0/TransformerBlock_11/feed_forward/w1/kernel | (2048,) | float32 | 2,048 | 0.0107    | 0.166   |
# | classifier/Transformer_0/TransformerBlock_11/feed_forward/w2/kernel | (768,)  | float32 | 768   | 0.00313   | 0.348   |
# | classifier/Transformer_0/TransformerBlock_11/feed_forward/w3/kernel | (2048,) | float32 | 2,048 | 0.00132   | 0.196   |
# | classifier/Transformer_0/TransformerBlock_2/Dense_0/bias            | ()      | float32 | 1     | 0.00162   | 0.0     |
# | classifier/Transformer_0/TransformerBlock_2/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0406   | 0.193   |
# | classifier/Transformer_0/TransformerBlock_2/attention/wk/kernel     | (768,)  | float32 | 768   | -0.0036   | 0.115   |
# | classifier/Transformer_0/TransformerBlock_2/attention/wo/kernel     | (768,)  | float32 | 768   | 0.000152  | 0.137   |
# | classifier/Transformer_0/TransformerBlock_2/attention/wq/kernel     | (768,)  | float32 | 768   | 0.00396   | 0.0923  |
# | classifier/Transformer_0/TransformerBlock_2/attention/wv/kernel     | (768,)  | float32 | 768   | 0.00131   | 0.0362  |
# | classifier/Transformer_0/TransformerBlock_2/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | -0.0263   | 0.0991  |
# | classifier/Transformer_0/TransformerBlock_2/feed_forward/w2/kernel  | (768,)  | float32 | 768   | -0.00658  | 0.191   |
# | classifier/Transformer_0/TransformerBlock_2/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | 0.0024    | 0.0972  |
# | classifier/Transformer_0/TransformerBlock_3/Dense_0/bias            | ()      | float32 | 1     | -0.00228  | 0.0     |
# | classifier/Transformer_0/TransformerBlock_3/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0277   | 0.145   |
# | classifier/Transformer_0/TransformerBlock_3/attention/wk/kernel     | (768,)  | float32 | 768   | -0.000652 | 0.169   |
# | classifier/Transformer_0/TransformerBlock_3/attention/wo/kernel     | (768,)  | float32 | 768   | 0.00726   | 0.161   |
# | classifier/Transformer_0/TransformerBlock_3/attention/wq/kernel     | (768,)  | float32 | 768   | 0.0106    | 0.177   |
# | classifier/Transformer_0/TransformerBlock_3/attention/wv/kernel     | (768,)  | float32 | 768   | -0.00445  | 0.171   |
# | classifier/Transformer_0/TransformerBlock_3/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | 0.0164    | 0.179   |
# | classifier/Transformer_0/TransformerBlock_3/feed_forward/w2/kernel  | (768,)  | float32 | 768   | 0.0027    | 0.194   |
# | classifier/Transformer_0/TransformerBlock_3/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | -0.000481 | 0.198   |
# | classifier/Transformer_0/TransformerBlock_4/Dense_0/bias            | ()      | float32 | 1     | -0.00249  | 0.0     |
# | classifier/Transformer_0/TransformerBlock_4/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0439   | 0.141   |
# | classifier/Transformer_0/TransformerBlock_4/attention/wk/kernel     | (768,)  | float32 | 768   | 0.00238   | 0.162   |
# | classifier/Transformer_0/TransformerBlock_4/attention/wo/kernel     | (768,)  | float32 | 768   | -0.00218  | 0.24    |
# | classifier/Transformer_0/TransformerBlock_4/attention/wq/kernel     | (768,)  | float32 | 768   | 0.00128   | 0.148   |
# | classifier/Transformer_0/TransformerBlock_4/attention/wv/kernel     | (768,)  | float32 | 768   | -0.00414  | 0.204   |
# | classifier/Transformer_0/TransformerBlock_4/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | 0.05      | 0.163   |
# | classifier/Transformer_0/TransformerBlock_4/feed_forward/w2/kernel  | (768,)  | float32 | 768   | 0.00217   | 0.192   |
# | classifier/Transformer_0/TransformerBlock_4/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | 0.00417   | 0.205   |
# | classifier/Transformer_0/TransformerBlock_5/Dense_0/bias            | ()      | float32 | 1     | -0.00223  | 0.0     |
# | classifier/Transformer_0/TransformerBlock_5/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0577   | 0.15    |
# | classifier/Transformer_0/TransformerBlock_5/attention/wk/kernel     | (768,)  | float32 | 768   | -0.0068   | 0.172   |
# | classifier/Transformer_0/TransformerBlock_5/attention/wo/kernel     | (768,)  | float32 | 768   | 0.000741  | 0.159   |
# | classifier/Transformer_0/TransformerBlock_5/attention/wq/kernel     | (768,)  | float32 | 768   | 0.00215   | 0.16    |
# | classifier/Transformer_0/TransformerBlock_5/attention/wv/kernel     | (768,)  | float32 | 768   | -0.00986  | 0.184   |
# | classifier/Transformer_0/TransformerBlock_5/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | -0.0224   | 0.172   |
# | classifier/Transformer_0/TransformerBlock_5/feed_forward/w2/kernel  | (768,)  | float32 | 768   | -0.0011   | 0.201   |
# | classifier/Transformer_0/TransformerBlock_5/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | 0.000998  | 0.2     |
# | classifier/Transformer_0/TransformerBlock_6/Dense_0/bias            | ()      | float32 | 1     | 0.00836   | 0.0     |
# | classifier/Transformer_0/TransformerBlock_6/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0474   | 0.154   |
# | classifier/Transformer_0/TransformerBlock_6/attention/wk/kernel     | (768,)  | float32 | 768   | -0.00763  | 0.165   |
# | classifier/Transformer_0/TransformerBlock_6/attention/wo/kernel     | (768,)  | float32 | 768   | -0.000425 | 0.175   |
# | classifier/Transformer_0/TransformerBlock_6/attention/wq/kernel     | (768,)  | float32 | 768   | -0.00355  | 0.169   |
# | classifier/Transformer_0/TransformerBlock_6/attention/wv/kernel     | (768,)  | float32 | 768   | -0.00498  | 0.182   |
# | classifier/Transformer_0/TransformerBlock_6/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | 0.0298    | 0.173   |
# | classifier/Transformer_0/TransformerBlock_6/feed_forward/w2/kernel  | (768,)  | float32 | 768   | 0.00316   | 0.178   |
# | classifier/Transformer_0/TransformerBlock_6/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | -0.00339  | 0.195   |
# | classifier/Transformer_0/TransformerBlock_7/Dense_0/bias            | ()      | float32 | 1     | 0.00985   | 0.0     |
# | classifier/Transformer_0/TransformerBlock_7/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.049    | 0.186   |
# | classifier/Transformer_0/TransformerBlock_7/attention/wk/kernel     | (768,)  | float32 | 768   | -0.00118  | 0.149   |
# | classifier/Transformer_0/TransformerBlock_7/attention/wo/kernel     | (768,)  | float32 | 768   | -0.0129   | 0.213   |
# | classifier/Transformer_0/TransformerBlock_7/attention/wq/kernel     | (768,)  | float32 | 768   | 0.0028    | 0.155   |
# | classifier/Transformer_0/TransformerBlock_7/attention/wv/kernel     | (768,)  | float32 | 768   | -0.00894  | 0.193   |
# | classifier/Transformer_0/TransformerBlock_7/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | 0.0227    | 0.17    |
# | classifier/Transformer_0/TransformerBlock_7/feed_forward/w2/kernel  | (768,)  | float32 | 768   | 0.014     | 0.19    |
# | classifier/Transformer_0/TransformerBlock_7/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | 0.0101    | 0.198   |
# | classifier/Transformer_0/TransformerBlock_8/Dense_0/bias            | ()      | float32 | 1     | 0.0113    | 0.0     |
# | classifier/Transformer_0/TransformerBlock_8/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0439   | 0.23    |
# | classifier/Transformer_0/TransformerBlock_8/attention/wk/kernel     | (768,)  | float32 | 768   | -0.00703  | 0.147   |
# | classifier/Transformer_0/TransformerBlock_8/attention/wo/kernel     | (768,)  | float32 | 768   | -0.00406  | 0.195   |
# | classifier/Transformer_0/TransformerBlock_8/attention/wq/kernel     | (768,)  | float32 | 768   | -0.00437  | 0.146   |
# | classifier/Transformer_0/TransformerBlock_8/attention/wv/kernel     | (768,)  | float32 | 768   | -0.00886  | 0.196   |
# | classifier/Transformer_0/TransformerBlock_8/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | -0.00744  | 0.17    |
# | classifier/Transformer_0/TransformerBlock_8/feed_forward/w2/kernel  | (768,)  | float32 | 768   | -0.00201  | 0.182   |
# | classifier/Transformer_0/TransformerBlock_8/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | 0.00575   | 0.196   |
# | classifier/Transformer_0/TransformerBlock_9/Dense_0/bias            | ()      | float32 | 1     | 0.00506   | 0.0     |
# | classifier/Transformer_0/TransformerBlock_9/Dense_0/kernel          | (4608,) | float32 | 4,608 | -0.0361   | 0.247   |
# | classifier/Transformer_0/TransformerBlock_9/attention/wk/kernel     | (768,)  | float32 | 768   | 0.000466  | 0.151   |
# | classifier/Transformer_0/TransformerBlock_9/attention/wo/kernel     | (768,)  | float32 | 768   | -0.00409  | 0.212   |
# | classifier/Transformer_0/TransformerBlock_9/attention/wq/kernel     | (768,)  | float32 | 768   | 0.00323   | 0.152   |
# | classifier/Transformer_0/TransformerBlock_9/attention/wv/kernel     | (768,)  | float32 | 768   | 0.00195   | 0.199   |
# | classifier/Transformer_0/TransformerBlock_9/feed_forward/w1/kernel  | (2048,) | float32 | 2,048 | 0.00413   | 0.164   |
# | classifier/Transformer_0/TransformerBlock_9/feed_forward/w2/kernel  | (768,)  | float32 | 768   | 0.0102    | 0.188   |
# | classifier/Transformer_0/TransformerBlock_9/feed_forward/w3/kernel  | (2048,) | float32 | 2,048 | 0.00668   | 0.203   |
# +---------------------------------------------------------------------+---------+---------+-------+-----------+---------+
# Total: 153,259.0 -- 613,036.0 bytes

# %%
# We can't do flax serialization so long as we're using grain for the data loader
# train_iter = checkpointed_state["train_iter"]
# Distribute training.
train_state = flax_utils.replicate(train_state)
train_step_func = functools.partial(
    train_step,
    model=model,
    optimizer=optimizer,
    train_metrics_class=metrics_class,
    learning_rate_fn=schedule_fn,
    ema_rate=config.ema_rate,
    num_microbatches=config.get("num_microbatches", None),
)
if config.check_nans:
    train_step_func = checkify.checkify(
        train_step_func, errors=checkify.float_checks
    )
p_train_step = jax.pmap(train_step_func, axis_name="batch", donate_argnums=(0,))
p_eval_step = jax.pmap(
    functools.partial(
        eval_step,
        model=model,
        eval_metrics_class=metrics_class,
        ema_rate=config.ema_rate,
    ),
    axis_name="batch",
)
hooks = []
report_progress = periodic_actions.ReportProgress(
    num_train_steps=num_train_steps, writer=writer
)
if jax.process_index() == 0:
    hooks += [
        report_progress,
        periodic_actions.Profile(num_profile_steps=5, logdir=workdir),
    ]
train_metrics = None
# Unreplicating from TPU is costly, so we only do it once at the start.
# initial_step = int(flax.jax_utils.unreplicate(train_state.step))
initial_step = checkpointed_state["step"]
logging.info("Initial step is %d", initial_step)

# %%
batch = utils.reshape_batch(next(train_iter))

# if config.check_nans:
#     errs, (train_state, metrics_update) = p_train_step(
#         train_state=train_state, batch=batch
#     )
#     errs.throw()
# else:
#     train_state, metrics_update = p_train_step(train_state=train_state, batch=batch)
# metric_update = flax_utils.unreplicate(metrics_update)

# train_metrics = (
#     metric_update if train_metrics is None else train_metrics.merge(metric_update)
# )
# Out:
# 2025-04-24 09:22:59.106248: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.119950: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.120216: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.120318: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.120347: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.148462: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.148462: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.162150: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.164289 1797106 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.177371 1797108 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.177690 1797105 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.177863 1797098 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.177966 1797092 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745486579.181928 1797106 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-24 09:22:59.183267: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.187690: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.187868: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.187944: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:22:59.188002: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1745486579.194736 1797108 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.195029 1797105 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.195309 1797092 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.195414 1797098 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.205704 1797101 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745486579.205710 1797112 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-24 09:22:59.214860: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.219115 1797096 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-24 09:22:59.222313: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1745486579.223043 1797101 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.223045 1797112 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.236448 1797096 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.240094 1797110 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.244335 1797094 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.244810 1797099 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.244972 1797109 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.245265 1797103 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745486579.257514 1797110 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.261549 1797094 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.262071 1797099 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.262274 1797109 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.262547 1797103 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.272384 1797111 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745486579.279720 1797107 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745486579.289829 1797111 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745486579.297044 1797107 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import jax.random as jr
from jax.scipy.special import logsumexp
import tensorflow_probability.substrates.jax as tfp

tfd = tfp.distributions

def test_ancestral_sample_step_informed(self, rng, i, timesteps, zt, conditioning=None):

    B, D = zt.shape[:2]

    rng_body = jax.random.fold_in(rng, i)
    s, t = self.get_sampling_grid(i, timesteps)
    cond = self.get_cond_embedding(conditioning)

    alpha_t = self.noise_schedule.alpha(t)
    alpha_s = self.noise_schedule.alpha(s)

    rng_pstep, rng_cstep = jr.split(rng_body, 2)

    # Predictor (ancestral)
    logits, _ = self.predict_x(zt, t, cond=cond)
    mean_preds = jax.nn.softmax(logits, axis=-1)

    unmask_prob = (alpha_s - alpha_t) / (1 - alpha_t)
    probs_vocab = unmask_prob * mean_preds

    probs_mask = jnp.ones(list(zt.shape) + [1]) * (1 - unmask_prob)
    probs = jnp.concatenate([probs_vocab, probs_mask], axis=-1)

    to_unmask = tfd.Categorical(probs=probs).sample(seed=rng_pstep)
    is_mask = zt == self.vocab_size
    zs = jnp.where(is_mask, to_unmask, zt)

    if self.k == 0:
        return zs

    # Corrector (gibbs)
    rng_cstep_1, rng_cstep_2 = jr.split(rng_cstep, 2)
    logits, _ = self.predict_x(zs, s, cond=cond)
    logits -= logsumexp(logits, axis=-1, keepdims=True)
    mean_preds = jax.nn.softmax(logits, axis=-1)

    jump_target = tfd.Categorical(probs=mean_preds).sample(seed=rng_cstep_1)
    # Figure out locations with the lowest score
    # Since the score is proportional to the denoising prob anyways, we're just gonna use the logits again
    b_idx, d_idx = jnp.indices((B, D))
    scores = logits[b_idx, d_idx, zs]
    # Add temperature annealing
    # This is minus since conventionally we add noise and take max
    scores -= self.gibbs_temp * jr.gumbel(rng_cstep_2, shape=(B, D))
    is_mask = zs == self.vocab_size
    scores = jnp.where(is_mask, jnp.inf, scores)
    
    # Trick: sort and then find the kth smallest
    thres = jnp.sort(scores, axis=-1)[:, self.k-1:self.k]
    zs_corr = jnp.where((scores <= thres) & (zs != self.vocab_size), jump_target, zs)

    return zs, zs_corr

def ancestral_sample_step(self, rng, i, timesteps, zt, conditioning=None):
    rng_body = jax.random.fold_in(rng, i)
    s, t = self.get_sampling_grid(i, timesteps)
    cond = self.get_cond_embedding(conditioning)

    alpha_t = self.noise_schedule.alpha(t)
    alpha_s = self.noise_schedule.alpha(s)

    logits, _ = self.predict_x(zt, t, cond=cond)
    mean_preds = jax.nn.softmax(logits, axis=-1)

    unmask_prob = (alpha_s - alpha_t) / (1 - alpha_t)
    probs_vocab = unmask_prob * mean_preds

    probs_mask = jnp.ones(list(zt.shape) + [1]) * (1 - unmask_prob)
    probs = jnp.concatenate([probs_vocab, probs_mask], axis=-1)

    to_unmask = tfd.Categorical(probs=probs).sample(seed=rng_body)
    is_mask = zt == self.vocab_size
    zs = jnp.where(is_mask, to_unmask, zt)
    return zs, zs

def ancestral_sample_step_uninformed(self, rng, i, timesteps, zt, conditioning=None):

        rng_body = jax.random.fold_in(rng, i)
        s, t = self.get_sampling_grid(i, timesteps)
        cond = self.get_cond_embedding(conditioning)

        alpha_t = self.noise_schedule.alpha(t)
        alpha_s = self.noise_schedule.alpha(s)

        rng_pstep, rng_cstep = jr.split(rng_body, 2)

        # Predictor (ancestral)
        logits, _ = self.predict_x(zt, t, cond=cond)
        mean_preds = jax.nn.softmax(logits, axis=-1)

        unmask_prob = (alpha_s - alpha_t) / (1 - alpha_t)
        probs_vocab = unmask_prob * mean_preds

        probs_mask = jnp.ones(list(zt.shape) + [1]) * (1 - unmask_prob)
        probs = jnp.concatenate([probs_vocab, probs_mask], axis=-1)

        to_unmask = tfd.Categorical(probs=probs).sample(seed=rng_pstep)
        is_mask = zt == self.vocab_size
        zs = jnp.where(is_mask, to_unmask, zt)

        # Corrector (uninformed)
        # Need to compute the backward rates from the logits
        # then sample with euler step...
        MASK = self.vocab_size

        logits, _ = self.predict_x(zs, s, cond=cond)
        logits -= logsumexp(logits, axis=-1, keepdims=True)
        # Shape: [B, D, S]
        mean_preds = jax.nn.softmax(logits, axis=-1)

        B, D, S = logits.shape
        b_idx, d_idx = jnp.indices((B, D))

        def _euler_update(key, x, rates):
            eps = 1e-8
            # Mask out the self transitions
            rates = rates.at[b_idx, d_idx, x].set(0.0)
            sum_rates = jnp.sum(rates, axis=-1)
            # transition_logit = jnp.log(-jnp.expm1(-rates)) # Prob = 1 - exp(-rate)
            transition_logit = jnp.log(-jnp.expm1(-sum_rates))[...,None] + jnp.log(rates) - jnp.log(sum_rates + eps)[...,None]
            transition_logit = transition_logit.at[b_idx, d_idx, x].set(-sum_rates)
            
            out = jr.categorical(key, transition_logit).astype(jnp.int32)
            return out

        dalpha_s = self.noise_schedule.dalpha(s)
        # Compute the rate matrix
        # Shape: [B, D, S+1]
        rates = jnp.where(zs[...,None] != MASK, 
            # Forward rate = - dalphat / alphat
            # Shape: [1, 1, S+1]
            jnp.concatenate([jnp.zeros((S,)), jnp.array((-dalpha_s / alpha_s,))])[None, None],
            # Backward rate = - dalphat / (1 - alphat) * denoising_probs
            # Shape: [B, D, S+1]
            jnp.concatenate([mean_preds * (-dalpha_s / (1-alpha_s)), jnp.zeros((B, D, 1))], axis=-1)
        )
        
        # The forward_backward_corrector shouldn't be used when s is 0
        zs_corr = jax.lax.cond(s == 0, lambda x: x, 
            lambda x: _euler_update(rng_cstep, x, rates * self.uninformed_step_size * (t-s)), zs)

        return zs, zs_corr

model.test_sample_step = test_ancestral_sample_step_informed
model.ancestral_sample_step = ancestral_sample_step
model.ancestral_sample_step_uninformed = ancestral_sample_step_uninformed

# %%
# Copied and modified from sampling.py
def get_attr(train_state, key):
  if hasattr(train_state, key):
    return getattr(train_state, key)
  else:
    return train_state[key]

@functools.partial(jax.pmap, axis_name='batch', static_broadcasted_argnums=0)
def generate(model, train_state, rng, dummy_inputs, conditioning=None):
  """Generate samples from the diffusion model."""
  rng = jax.random.fold_in(rng, jax.lax.axis_index('batch'))
  variables = {
      'params': get_attr(train_state, 'ema_params'),
      **get_attr(train_state, 'state'),
  }
  rng, sub_rng = jax.random.split(rng)
  zt = model.apply(
      variables,
      dummy_inputs.shape[0],
      method=model.prior_sample,
      rngs={'sample': sub_rng},
  )
  rng, sub_rng = jax.random.split(rng)

  timesteps = model.timesteps

  print("Using sampler:" + model.sampler)

  if model.sampler == 'informed' or model.sampler == 'uninformed':
    timesteps //= 2

  print("Timesteps: " + str(timesteps))

  # def body_fn(i, zt):
  #   return model.apply(
  #       variables,
  #       sub_rng,
  #       i,
  #       timesteps,
  #       zt,
  #       conditioning=conditioning,
  #       # We are hard coding the sample step to be our test_sample_step
  #       method=model.test_sample_step,
  #   )

  # z0 = jax.lax.fori_loop(
  #     lower=0, upper=timesteps, body_fun=body_fn, init_val=zt
  # )

  if model.sampler == 'informed':
    method = model.test_sample_step
  elif model.sampler == 'uninformed':
    method = model.ancestral_sample_step_uninformed
  elif model.sampler == 'ancestral':
    method = model.ancestral_sample_step

  def step_fn(zt_corr, i):

    zt_pred, zt_corr = model.apply(
        variables,
        sub_rng,
        i,
        timesteps,
        zt_corr,
        conditioning=conditioning,
        method=method#model.test_sample_step,
    )

    return zt_corr, (zt_pred, zt_corr)

  # Use scan instead
  z0, out = jax.lax.scan(
      step_fn,
      init=zt,
      xs=jnp.arange(timesteps),
  )

  sample = model.apply(
      variables,
      z0,
      conditioning=conditioning,
      method=model.decode,
      rngs={'sample': rng},
  )

  return sample, out

# %%
model.sampler = "uninformed"

results_dict = {}

k = 8
tem = 1.0

model.k = k
model.gibbs_temp = tem

# for k in k_range:
#     for tem in tem_range:
#         results_dict[k, tem] = {}

timesteps = 256
model.timesteps = timesteps # Informed sampler will use half the timesteps


_, sample_rng = jax.random.split(rng)
dummy_loader = train_loader
dummy_batch = utils.reshape_batch(next(iter(dummy_loader)))
dummy_inputs = dummy_batch[config.task_type]

# # Only 1 sample per device
# dummy_inputs = dummy_inputs[:,:1]

if "label" in dummy_batch:
    conditioning = dummy_batch["label"].astype("int32")
else:
    conditioning = None

samples = generate(
    model,
    train_state,
    flax_utils.replicate(sample_rng),
    dummy_inputs,
    conditioning=conditioning,
)
# Out:
# 2025-04-24 09:36:14.979223: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.037295 1824483 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.054874 1824483 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-24 09:36:15.056764: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.056767: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.056767: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.064598: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.064598: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.064591: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.065673: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.114439 1824501 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.114443 1824495 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.114443 1824493 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.122286 1824502 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.122290 1824486 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.122290 1824503 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.122850 1824496 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.131881 1824501 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.131881 1824493 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.131882 1824495 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-24 09:36:15.134832: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.134884: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.137006: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# E0000 00:00:1745487375.139696 1824486 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.139699 1824503 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.139699 1824502 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.140165 1824496 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-24 09:36:15.140401: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.140401: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.140410: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-24 09:36:15.170275: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.192389 1824498 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.192438 1824492 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.193849 1824497 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.197924 1824500 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.197925 1824499 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.197924 1824504 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.209869 1824498 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.209875 1824492 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.211144 1824497 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.215312 1824504 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.215317 1824499 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745487375.215319 1824500 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745487375.227703 1824490 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745487375.245038 1824490 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using sampler:uninformed
# Timesteps: 128

# %%
all_samples = jax.pmap(
    lambda x: jax.lax.all_gather(x, "batch"), axis_name="batch"
)(samples)
all_samples = flax_utils.unreplicate(all_samples)
z0, (zt_pred, zt_corr) = all_samples
z0 = z0.reshape(-1, *data_shape)

predictor_steps = timesteps if model.sampler == "ancestral" else timesteps // 2

# zt_pred has shape (num_devices, num_steps, batch_size, seq_len)
# We want to swap axes and reshape to (num_steps, batch_size, seq_len)
zt_pred = jnp.swapaxes(zt_pred, 0, 1)
zt_pred = zt_pred.reshape(predictor_steps, -1, *data_shape)
zt_corr = jnp.swapaxes(zt_corr, 0, 1)
zt_corr = zt_corr.reshape(predictor_steps, -1, *data_shape)

tokenizer = dataset_info["tokenizer"]
# foo = lambda z: utils.detokenize_texts(z, tokenizer)
corr_text = np.apply_along_axis(tokenizer.decode, -1, zt_corr[:,0])
pred_text = np.apply_along_axis(tokenizer.decode, -1, zt_pred[:,0])

texts = utils.detokenize_texts(z0, tokenizer)

# zt_pred = jax.vmap(utils.detokenize_texts, in_axes=(0, None))(np.asarray(zt_pred), tokenizer)
# zt_corr = jax.vmap(foo)(np.array(zt_corr))

# all_samples = all_samples.reshape(-1, *data_shape)
# tokenizer = dataset_info["tokenizer"]
# texts = utils.detokenize_texts(all_samples, tokenizer)
# results_dict[k, tem] = texts

# %%
import numpy as np

def visualize_predictor_corrector(z_pred: np.ndarray, z_corr: np.ndarray,
                                  predictor_color: str = '\033[94m',  # Blue
                                  corrector_color: str = '\033[92m',  # Green
                                  reset_color: str = '\033[0m'):
    """
    Visualizes alternating predictor/corrector updates.

    Args:
        z_pred: Numpy array of shape (timesteps, seq_len), predictor outputs.
        z_corr: Numpy array of shape (timesteps, seq_len), corrector outputs.
        predictor_color: Color for predictor changes.
        corrector_color: Color for corrector changes.
    """

    alt_color = '\033[90m'  # Grey

    T = z_pred.shape[0]
    assert z_corr.shape[0] == T, "z_pred and z_corr must have same number of timesteps"
    # assert z_pred.shape[1] == z_corr.shape[1], "Sequence lengths must match"

    def highlight_diff(prev, curr, color, reset):
        return ''.join(
            f"{color}{c}{reset}" if c != p else f"{reset}{c}{reset}"
            for p, c in zip(prev, curr)
        )

    print(f"{''.join(z_pred[0])}")
    corr_highlight = highlight_diff(z_pred[0], z_corr[0], corrector_color, reset=alt_color)
    print(f"{corr_highlight}")
    for t in range(1, T):
        # Predictor step
        pred_highlight = highlight_diff(z_corr[t-1], z_pred[t], predictor_color, reset=reset_color)
        print(f"{pred_highlight}")

        # Corrector step
        corr_highlight = highlight_diff(z_pred[t], z_corr[t], corrector_color, reset=alt_color)
        print(f"{corr_highlight}")

# z_pred = np.array([
#     list("__________"),
#     list("h_________"),
#     list("he________"),
#     list("hel_______"),
# ])

# z_corr = np.array([
#     list("__________"),
#     list("t_________"),
#     list("de________"),
#     list("hgl_______"),
# ])

count_to_visualize = 100

visualize_predictor_corrector(pred_text[-count_to_visualize:], corr_text[-count_to_visualize:])
# Out:
# |||||||||||||||||||||||h||e|||e|||||||||||e |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||o|||||||||||||||||||||||e||t||||g|||||||||||||||h||||||||||||||||||||||a||||||||v|||||||||||||||||||i|||||||||||||||a|||||||||||||||||||t||||||
# |||||||||||||||||||||||h||e|||e|||||||||||e |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||o||||||||||m||||||||||||e||t||||g|||||||||||||||h||||||||||||||||||||||ac|||||||v|||||||||||||||||||i|||||||||||||||a|||||||||||||||||||t||||||
# |||||||||||||||||||||||h||e|||e|||||||||||e |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||o||||||||||m||||||||||||e||t||||g|||||||||||||||h||||||||||||||||||||||ac|||||||v|||||||||||||||||||i|||||||||||||||a|||||||||||||||||||t||||||
# |||||||||||||||||||||||h||e|||||||n|||||||e |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||o||||||||||m||||||||||||e||t||||g|||||||||||||||h||||||||||||||||||||||ac|||||||v|||||||||||||||||||i|||||||||||||||a|||||||||||||||||||t||||||
# |||||||||||||||||||||||h||e|||||||n|||||||e |||||||||||||||||||||||||||||||||||||||||||| ||||||||||||||||||||||||o||||||||||m||||||||||||e||t||||g|||||||||||||||h|||||||||||||t||||||||ac|||||||v|||||||||||||||||||i|||||||||||||||a|||||||||||||||||||t||||||
# ||||||||||||||||||||||||||e|||||||n|||||||e |||||||||||||||||||||||||||||||||||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||||t||||||||ac|||||||v|||||||||||||||||||||||||||||||||||a|||||||||||||||||||t||||||
# ||||||||||||||||||||||||||e|||||||n|||||||e ||||||||||||||||||||||||||m||||||||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||||t||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a|||||||||||||||||||t||||||
# ||||||||||||||||||||||||||e|||||||n|||||||e ||||||||||||||||||||||||||m||||||||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||||t||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a|||||||||||||||||||t||||||
# ||||||||||||||||||||||||||e|||||||n|||||||e ||||||||||||||||||||||||||me|||||||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||| t||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||||||||||e|||||||n|||||||e ||||||||||||||||||||||||||me|||||||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||| t||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||i|||||||||||||||||||e|||||||n|||||||e ||||||||||||||||||||||||||me|||||||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||| t||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||||||||||e|||||||n|||||||e ||||||||||||||||||||||||||me|||||||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||| t||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||||||e ||||||||||||||||||||||||||me||||f||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||| t||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||||||e ||||||||||||||||||||||||||me||||f||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||| |||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||||||e ||||||||||||||||||||||||||me||||f||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||h|||||||||||| |||t|||||ac|||||||v|||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||||||e ||||||||||||||||||||||||||me||||f||||||||||| ||||||||||||||||||||||||o||||||||||m|||||||||||||||t||||g|||||||||||||||||||||||||||| |||t|||||ac|||||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||||||e ||||||||||||||||||||||||||me||||f||||||||||| |||||||||||||||||||e||||o||||||||||m|||||||||||||||t||||g|||||||||||||||||||||||||||| |||t|||||ac|||||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||||||e |||||||||||||||||||||||||||e||||f||||||||||| |||||||||||||||||||e||||o||||||||||m|||||||||||||||t||||g|||||||||||||||||||||||||||| |||t|||||ac||d||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e ||||||||||||||||e||||||||||e||||f||||||||||| |||||||||||||||||||e||||o||||||||||m|||||||||||||||t||||g|||||||||||||||||||||||||||| |||t|||||ac||d||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e|||||||||||||||||e||||||||||e||||f||||||||||| |||||||||||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac||d||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e|||||||||||||||||e||||||||||e||||f||||||||||| |||||| ||||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac||d||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e|||||||||||||||||e||||||||||e||||f||||||||||| |||||| ||||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac||d||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e|||||||||||||||||e||||||||||e||||f||||||||||| |||||| |e||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac||d||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e|||||||||||||||||e||||||||||e||||f||||||||||| |||||| |e||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac||d||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge||||||||||e||||f||||||||||| |||||| |e||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac||d||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge||||||||||e||||f||||||||||| |||||| |e||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac|||||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge||||||||||e||||f||||||||||| |||||| |e||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac|||||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge||||||||||e||||f||||||||||| |||||| |e||||||||||e||||o||||||||||m|||||||||||||||t||a|g|||||||||||||||||||||||||||| |||t|||||ac|||||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge||||||||||e||||f||||||||||| |||||| |e||||||||||e||||o||||||||||m|||||||||||l|||t||a|g|||||||||||||||||||||||||||| |||t|||||ac|||||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge||||||||||e||||f||||||||||| ||||||||e||||||||||e||||o||||||||||m|||||||||||l|||t||a|g|||||||||||||||||||||||||||| |||t|||||ac|||||||||||||||||||||||||||||||||||||||||||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||||||| ||||||||e||||||||||e||||o||||||||||m|||||||||||l|||t||a|g|||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||||||t||||||
# ||||||||||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||||||| ||||||||e||||||||||e||||o||||||||||m|||||||||||l|||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||||||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||a|||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||l|||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||||||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||a|||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||l|||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||||||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||a|||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||l|||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||||||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||a|||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||||||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||a|||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||||||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||||||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||||||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||||||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||e|||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e||||||||||||||||ge|||||e||||e||||f||||||||||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||||||||||||||| |||a||||l||||||||||e|||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||| ||||||||||| |||a||||l||||||||||e|||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge||||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||| ||||||||||| |||a||||l||||||||||e|||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge|r||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||| |s||||||||| |||a||||l||||||||||e|||t||||||
# ||||||t|||||||||||s|||||||e|||||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge|r||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||||||||||| |s||||||||| |||a||||l||||||||||e|||t||||||
# ||f|||t|||||||||||s|||||||e|||||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||e|||||n||||e||||o||||||||||m|||||||||||||||t||a|ge|r||||||||||||||||||||||||| |||t|||||ac||||||||||||||||||| ||||||| |s||||||||| |||a||||l||||||||||e|||t||||||
# ||f|||t|||||||||||s|||||||e|l|||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||e||||||||||e||||o||||||||||m|||||||||||||||t||a|ge|||||||||||||||||||||||||||||||t|||||ac||||||||||||||||||| a|||||| |s||||||||| |||a||||l||||||||||e| |t||||||
# ||f|||t|||||||||||s|||||||e|l|||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||e||||||||||e||||o||||||||||m|||||||||||||||t||a|ge|||||||||||f||||t||||||||||||||t|||||ac||||||||||||||||||| a|||||| |s||||||||| |||a||||l||||||||||e| |t||||||
# ||f|||t|||||||||||s|||||||e|l|||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||ea|||||||||e||||o||||||||||m|||||||||||||||t||a|ge|||||||||||f||||t||||||||||||||t|||||ac||||||||||||||||||| a|||||| |s||||||||| |||a||||l||||||||||e| |t||||||
# ||f|||t|||||||||||s|||||||e|l|||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||ea|||||||||e||||o||||||||||m|||||| ||||||||t||a|ge|||||||||||f||||t|||||k||||||||t|||||ac||||||||||||||||||| a|||||| |s||||||||| |||a||||l||||||||||e| |t||||||
# ||f|||t|||||||||||s|||||||e|l|||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||ea|||||||||e||||o||||||||||m||| || ||||||||t||a|ge|||||||||||f||||t|||||k||||||||t|||||ac||||||||||||||||||| at||||| |s||||||||| |||a||||l||||||||||e| |t||||||
# ||f|||t|||||||||||s|||||||e|l|||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||m|| |||t||||ea||n||||||e||||o||||||||||m||| || ||||||||t||a|ge|||||||||||f||||t|||||k||||||||t|||||ac||||||||||||||||||| at||||| |s||||||||| |||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s|||||||e|l|||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||ea||n||||||e||||o||||||||||m||| || ||||||||t||a|ge|||||||||||f||||t|||||k||||||||t|||||ac||||||||||||||||||| at||||| |s||||||||| |||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s|||||||e|l|||||n|||f|||e|||l||||||| ||||ge|||||e||||e||||f||||||||||| |||t||||ea||n||||||e||||o||||||||||m|k| || ||||||||t||a|ge|||||||||||f||||t|||||k||||||||t|||||ac||||||||||||||||||| at||||| |s||||||||| |||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s|||||||e|l|||||nd||f|||e|||l||||||| ||||ge|||||e||||e|||||||||||||||| |||t||||ea||n|||||||||||o||||||||||m|k| || ||||||||t||a|ge|||||||||||f||||t|||||k||||||||t|||||ac||||||||||||||||||| at |||| |s||||||||| |||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s|||||||e|l|||||nd||f|||e|||l||||||| ||||ge|||||e||||e|||||||||||y|||| m||t||||ea||n|||||||||||o|||||| |||mak| || ||||||||t||a|ge|||||||||||f||||t|||||k||||||||t|||||ac||||||||||||||||||| at |||| |s||||||||| |||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s|||||||e|l|||||nd||f|||e|||l||||||| ||||ge|||||e||||e|||||||||||y|||| m||t||||ea||n|||||||||||||||||| |||mak| || ||||||||t||a|ge|||||||||||f||||t|||||k||||||||t|||||ac||||||||||||||||||| at |||| |s||||||||| |||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s|||||||e|l|||||nd||f|||e|||l||||||| |||rge|||||e||||e|||||||||||y|||| m||t||||ea||n|||||||||||||||||| |||mak| || ||||||||t||a|ge|||||||||||f|r||t|||||k||||||||t|||||ac||||||||||||e|||||| at |||| |s||||||||| |||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s||||||he|l|||||nd||f|||e|||l||||||| |||rge|||||e||||e|||||||||||y|||| my|t||||ea||ng||||||||||||||||| |||mak| || ||||||||t||a|ge|||||||||||f|r||t|||y|k||||||||t|||||ac||||||||||||e|||||| at |||| |s|||||||||||||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s|||e||he|l|||||nd||f|||e|||l||||||| |||rge|||||e||||e|||||||||||y|||a my|t||||ea||ng|||||||w||||||||| |||mak| || ||||||||t||a|ge|||||||||||f|r||t|||y|k||||||||t|||||ac||||||||||||e|||||| at |||| |s|||||||||||||a||||l||||||||||e| |t|l||||
# ||f|||t|||||||||||s|||e||he|l|||||nd||f|||e|||l||||||| |||rge|||||e||||e|||||||||||y|||a my|t||||ea||ng|||||||w||||||||| |||mak| || ||||||||t||a|ge|||||||||||f|r||t|||y|k||||||||t|||||ac||||||||||||e|||||| at |||| |s|||||||||||||a||||l||||||||||e| |t|l||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|||e|||l||||||| |||rge|||||e||||e ||||||||||y|||a my|t||||ea||ng|||||||w||||||||| |||mak| || ||||||||t||a|ge|||||||||||f|r||t|||y|k||||||||t|||||ac||||||||||||e|||||| at |||| |s|||||||||||||a||||l||||||||||e| |t|l||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|||e|||l||||||| |||rge|||||e||||e|||||||||||y|||a |y|t||||ea||ng|||||||w||||||||| |||mak| || |||||||||||a|ge|||||||||||f|r||t|||y|k||||||||t||e||ac||||||||||||e|||||| a| |||| |s|||||||||||||a||||l||||||||||e| |t|l||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|t|e|||l||||||| |||rge|||||e||||e|||ne| ||||y|||a |y|t||||ea||ng|||||||w||||||||| |||mak| || |||e|||||||a|ge|||||||||||f|r||t|||y|k||||||||t||e||ac||||||||||||e|||||| a| |||| |s|||||||||||||a||||l||||||||||e| |t|l||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|t|e|||l||||||| |||rge|||||e||||e|||ne| ||||y|||a |y|t||||ea||ng|||||||w||||||||| |||mak| || |||e|||||||a|ge|||||||||||f|r||t|||y|k||||||||t||e|||c||||||||||||e|||||| a| |||| |s||||||||||||||||||l||||||||||e| |t||||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|t|e|||l||||||| |||rge|||||e||||e|||ne| ||||y|||a |y|t||||ea||ng|||||||w|||||||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|||y|k||||||||t||e|||c|||s||||||||e|||||| a| |||| |s||||||||||||||||||l||||||||||e| |t||||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|t|e|||l||||||| |||rge|||||e||||e|||ne| ||||y|||a |y|t||||ea|ing|||||||w||||p||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|||y|k||||||||t||e|||c|||s|||||||te|||||| a| |||| |s||||||||||||||||||l||||||||||e| |t||||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|the|||l|||||i| |||rge|||||e||||e|||ne| ||||y|||a |y|t||||ea|ing|||e|||w||||p||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|||y|k||||||||t||e|||c|r|s|||||||te|||||| a| |||| |s|t||||||||||||||||l||||||||||e| |t||||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|the|||l|||||i| |||rge|||||e||||||||ne| ||||y|||a |y|t||||ea|ing|||e|||w||||p||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|||y|k||||||||t||e|||c|r|s|||||||te|||||| a| |||| |s|t||||||||||||||||l||||||||||e| |t||||||
# ||f||ht|||||||||||s|||e||he|l|||||nd||f|the|||l|||||i| c||rge|||||e||||||||ne| ||||y|||a |y|t||||ea|ing|||e|||w||||p||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|||y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t||||||||||||||||l|||||||n||e| |t||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l|||||i| c||rge|||||e||||||||ne| ||||y|||a |y|t||||ea|ing|||e|||w||||p||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|l|y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t||||||||||||||||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l|||||i| c||rge|||||e||||||||ne| ||||y|| a |y|t||||ea|ing|||e|||w||||p||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|l|y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t||||||||||||||||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l|||||i| c||rge|||||e||||||||ne| ||||y|| a |y|t||||ea|ing|||e||||||||p||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|l|y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t||||||||||||||||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l|||||is c||rge|||||e||||||||ne| ||||y|| a |y|t||||ea|ing|||e||||||||p||c| |||mak| || |||en||||||a|ge|||||||||||f|r||t|l|y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t||||||||||||||||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l|||||is c||rge|||||e||||||||ne| ||||y|| a |y|t||||e||ing|||e||||||||p||c| |||mak| || |||en||||||||ge|||||||||||f|r||t|l|y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t|||||||t||||t|||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l||e||is c||rge|||||e||||||||ne| ||||y|| a |y|t||||e||ing|||e||||||||p||c| |||mak| || |||en||||||||ge|||||||||||f|r||t|l|y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t|||||||t||||t|||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l||e||is c||rge|||||e||||||a|ne| ||||y|| a |y|t||||e||ing|||e||||||||p||c| |||mak| || |||en||||||i|ge|||||||||||f|r||t|l|y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t|||||||t||||t|||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l||e||is c||rge|||||e||||||a|ne| ||||y|| a |y|t||||e||ing|||e||||||||p||c| |||mak| || |||en||||||i|ge|||||||||||f|r||t|l|y|k||||||||t||e|||c|r|s||||||ste|||||| a| |||| |s|t|||||||t||||t|||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f|the|||l||e||is c||rge|||||e||||||a|ne| ||||y|| a |y|t||||e||ing||||||||||||p||c| |||mak| || |||en||||||i|ge|||||||||||f|r||t|l|y|k||||||||t||e|||||r|s||||||ste|||||| a| |||| |s|t|||||||t||||t|||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the|||l||e||is c||rge|||||e||||||a|ne| ||||y|| a |y|t||||e||ing||||||||||||p||c| |||mak| || |||en||||||i|ge|||||||||||f|r||t|l|y|k||||||||t||e|||||r|s||||||ste|||||| a| ||l| |s|t|||||||t||||t|||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the|||l||e||is c||rge|||||e||||||a|ne| ||||y|| a |y|t||||e||ing||||||||||||p||c| |||mak| || |||en||||||i|ge|||||||||||||r||t|l|y|k||||||||t||e|||||r|s||||||ste|||||| a| ||l| |s|t|||||||t||||t|||l|||||||n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the|||l||e||is c||rge|||||e||||||a|ne| ||| y|| a |y|t||||e||ing||||||||||||p|ec| |||mak| || |||en||||||i|ge|||||||||||||r||t|l|y|k||||||||t||e|||||r|s||||||ste|||||| a| ||l| |s|t|||||||t||||t|||l|||||m|n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the|||l||e||is c||rge|||||e||||||a|ne| ||| y|| a |y|t||||e||ing||||||||||||p|ec| |||mak| || |||en||||||i|ge|||||||||||||r||t|l|y|k||||||||t||e|||||r|s||||||ste|||||| a| ||l| |s|t|||||||t||||t|||l|||||m|n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the|||l||e||is c||rge|||||e||||||a|ne| ||| y|| a |y|t||||e||ing||h|||||||||p|ec| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||ste|||||| a| ||l| |s|t|||||||t||||t|||l|||||m|n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the|||l||e||is c||rge|||||e||||||a|ne| ||| y|| a |y|t||||e||ing||h|||||||||p|ec| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||ste||t||| a| ||l| |s|t|||||||t||||t|||l|||||m|n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the||al||e||is c||rge|||||e||||||a|ne| ||| y|| a |y|t||||e||ing||h|||||||||p|ec| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||ste||t||| a| ||l| |s|t|||||||t||||t|||l|||||m|n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the||al||e||is|c||rge|||||e||||||a|ne| ||| y|| a |y|t||||e||ing||h|||||||||p|ec| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||s|e||t||| a| ||l| |s|t|||||||t||||t|||l|||||m|n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the||al||e||is|c||rge|||||e||||||a|ne| ||| y|| a |y|t|||se||ing||h|||||||||p|ec| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||s|e||t||| a| ||l| |s|t|||||||t||||t|||l|||||m|n||e| ||||||||
# |||||ht|||||||||||s|||e||he|l|||||nd||f the||a|||e||is|c||rge|||||e||||||a|ne| ||| y|| a |y|t|||s|||ing||h|||||||||p|ec| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|||||m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd||f the||a|||e||is|c||rge|||||e||||||a|ne| ||| y|| a |y|t|||s|||ing||h|||||||||p|ec| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|||||m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd||f the||a|||e||is|c||rge|||||e||||||a|ne| ||| y|| a |y|t|||s|||ing||h|||||||||p|e|| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|||||m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd||f the||a|||e||is|c||rge|||||e||||||a|ne| ||| y|| a |y|t|||s||ying||h|||||||||p|e|| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|||d|m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd||f the||a|||e||i||c||rge|||||e||||||a|ne| ||| y|| | |y|t|||s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|||d|m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd |f the||a|||e||i||c||rge|||||e||||||a|ne| ||| y|t | |y|t|||s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge||||||||| |||r||t|l|y|k|||||m||ti|e|||||r|s||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|||d|m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd |f the||a|||e||i||c||rge|||||e||||||a|ne| ||| y|t | |y|t|||s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge||||||||| ||||||t|l|y|k|||||m||ti|e|||||r||||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|||d|m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd |f the||a|||e||i||c||rge|||||e||||||a|ne| ||| y|t | |y|t|||s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge||||||||| ||||||t|l|y|k|||||m||ti|e|||||r||||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|||d|m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd |f the||a|||e||i||c||rg||||||e||||||a|ne| |h| y|t|| |y|t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge||||||||| ||||||t|l|y|k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|| d|m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd |f the||a|||e||i||c||rg||||||e||||||a|ne| |h| y|t|| |y|t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge||||||||| ||||||t|l|y|k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|| d|m|n||e| ||||||||
#  ||||ht|||||||||||s|||e||he|l|||||nd |f the||a|||e||i||c||rg| ||||e||||||a|ne| |h| y|t|| |y|t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge||||||||| ||||||t|l|y|k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| |s|t||||||||||||t||al|| d|m|n||e| ||||||||
#  ||i|ht|||||||||||s|||e||he|l|||||nd of the||a|i|e||i||c||rg| ||||e||||||aine| |h| y|t|| |y|t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge||||||||| ||||||t|l|y|k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| as|t||||||||||||t||al|| d|m|n||e| ||||||w|
#  ||i|ht|||||||||||s|||e||he|l|||||nd of the||a|i|e||i||c||rg| ||||e||||||a|ne| |h| y|t|| |||t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge|w||||||| ||||||t|l|y|k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| as|t||||||||||||t||al|| d|m|n||e| ||||||w|
#  ||i|ht|||||||||||s|||e||he|l|||||nd of the||a|i|e||i||c||rg| ||||e||||||a|ned |h| y|t|| |||t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge|w||||||| ||||||t|l|y|k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| as|t||||||||||||t||al|| d|m|n||e| |h||||w|
#  ||i|ht|||||||||||s|||e||he|l|||||nd of the||a|i|e||i||c||rg||||||e||||||a|ned |h| y|t|| |||t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge|w||||||| t|||||t|l|||k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| as|t||||||||||||t||al|| d|m|n||e| |h||||w|
#  ||i|ht|||||||||||s|||e||he|l||t||nd of the||a|ine||i||c||rg||||||e||||||a|ned |h| y|t|| |||t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge|w||||||| t|||||t|l|||k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| as|t||||||||||||t||al|| d|m|n||e| |h||||w|
#  ||i|ht|||||||||||s|||e||he|l||t||nd of the||a|ine||i||c||rg||||||e||||||a|ned |h| y|t|| |||t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge|w||||||| t|||||t|l|||k|||||m||ti|e|||||r|m||||||s|e||t||| a| ||l| as|t||||||||||||t||al|| d|m|n||e| |h||||w|
#  ||i|ht|||||||||||s|||e||he|l||t||nd of the||a|ine||i||c||rg|||e||e||||||a|ned |h| y|t|| |||t|| s||ying||h||||o||||p|e|| |||mak| || |||en||m|||i|ge|w||||||| t|||||t|l|||k|||||m| ti|e|||||r|m||||||s|e||th|| a| ||l| as|t|||||||n||||t||al|| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s|||e||he|l||t||nd of the||a|ine||i||c||rg|||e||e||||||a|ned |h| y|t|| |||t|| s||ying||h||||o||||pme|| |||mak| || |||en||m|||i|ge|w||||||| t|||||t|l|||||v|||m| ti|e|||||r|m||||||s|e||th|| a| ||l| as|t|||||||n||||t||al|| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s|||e||he|l||t||nd of the||a|ine||in|c||rg|||e||e||||||a|ned |h| y|t|| |||t|| s||ying||h||||o||||pme|| |||mak| || |||en||m|||i|ge|w||||||| t|||||t|l|||||v|||m| ti|e||f||r|m||||||s|e||th|| a| ||l| as|t|||| ||ni|||t||al|| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s||||||he|l||t||nd of the||a|i|e||in|c||rg|||e||e||||||a|ned |h| y|t|| |||t|| s||ying||h||||o||||pme|| |||mak|||| |||en||m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|| a| ||l| as|t|||| ||ni|||t||al|| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s|||g||he|l||t||nd of the||a|i|e||in|ch|rg|||e||e||||||a|ned |h| y|t|| ||it|| s||ying||h||||o||||pme|| |||mak|||| |||en||m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|| a| ||l| as|t|||| ||ni|||t||ali| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s|||g||he|l|ft||nd of the||a|i|e||in|ch|rg|||e||e||||||a|ned ||| yat|| ||it|| s||ying||h||||o||||pme|| |||mak|||| |||en||m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|| a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s|||g||he l|ft||nd of the||a|i|e||in|ch|rg|||e||e||||||a|ned ||| yat|| ||it|| s||ying||h||||o||||pme|| |||mak|||| |||en||m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|| a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s|||g||he l|ft||nd of the||a|i|e||in|ch|rg|||e||e||||||a|ned ||| yat|| ||it|| s||ying||h||||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|| a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s|||g||he l|ft||nd of the|ca|i|e||in|ch|rg|||e||e||||||a|ned ||| yat|| ||it|| s|eying||h||||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|| a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| |he|||w|
#  ||i|ht|||||||||||s|||g||he l|ft||n| of the|ca|i|e||in|ch|rg|||e||e||||||a|ned ||| yat|| ||it|| s|eying||h||||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| ||e|||w|
#  ||i|ht|||||||||||s|||g||he l|ft||n| of the|ca|i|e||in ch|rg|||e||e||||||a|ned ||| yat|| ||it|| s|eying||h||||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| ||e|||w|
#  ||i|ht||||||||b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e||e||||||a|ned ||| yat|| ||ite| s|eying||h||||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| ||e|||w|
#  ||i|ht||||||||b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e||e||||||a|ned ||| yat|| ||ite| s|eying||he|||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| ||e|||we
#  ||i|ht||||||||b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e||e||||||ained ||| yat|| ||ite| s|eying||he|||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| ||n||||t||ali| d|m|n||e| ||e|||we
#  ||i|ht||||||||b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e||e||||||ained ||| yat|| ||ite| s|eying||he|||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| m|n||||t||ali| d|m|n||e| ||e|||we
#  ||i|ht||||||t|b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e||e||||||ained ||| yat|| ||ite| s|eying||he|||o||||pme|| |||mak|||| |||end|m|||i|ge w||||||| t|||||t|l|||| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| m|n||||t||ali| d|m|n||e| ||e|||we
#  ||i|ht||||||t|b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e||e||||||ained ||| yat|| ||ite| s|eying||he|||o||||pme|| |||mak|||| |n|endim|||i|ge w||||||| t|||||til|t|| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| m|n||||t||ali| d|m|n||e| ||e|||we
#  ||i|ht||||||t|b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e||e||||||ained ||| yat|| ||ite| s|eying||hei||o||||pme|| |||mak|||| |n|endim|||i|ge w||||||| t|||||til|t|| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| m|n||||t||ali| d|m|n||e| ||e|||we
#  ||i|ht||||||t|b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e|be||||||ained ||| yat|| ||ite| s|eying|thei||o||||pme|| |||mak|||| |n|endim|||i|ge w||||||| t|||||til|t|| v|||m| ti|e||f||r|m||||||s|e||th|m a| ||l| as|t|||| m|n||||t|tali| d|m|n||e| t|er||we
#  ||i|ht||||||t|b||s||ng||he l|ft|an| of the|ca|i|e||in ch|rg|||e|be||||||ained ||| yat|| ||ite| s|eying|thei||o||||pme|| |||mak|||| |n|endim|||i|ge w||||||| t|||||til|t|| v|||m| ti|e |f||r|m||||||s|e||th|m a| ||l| as|t|||| m|n||||t|tali| d|m|n||e| t|er||we
#  ||i|ht||||||t|b||s||ng||he left|an| of the|ca|i|e||in ch|rg|||e|be||||||ained ||| yat|| ||ite| s|eying|thei||o|t||pme|| |||mak|||| |n|endim|||i|ge w||||||| t|||||til|t|| v|||m| ti|e |f||r|m||||||s|e||th|m a| ||l| as|th||| m|n||o|t|tali| d|m|n||e| t|er||we
#  ||i|ht||||||t|b||s||ng||he left|an| of the|ca|i|e||in ch||g|||e|be||||||a|ned ||| yat|| ||ite| s|eying|thei||o|t||pme|| |||mak|||| |n|endim|||i|ge w||||||| t|||||til|t|| v|||m| ti|e |f||r|m||||||s|e||th|m a| ||l| as|th||| m|n||o|t|tali| d|m|n||e| t|er||we
#  ||i|ht||||||t|b||s||ng||he left|an| of the|ca|i|et|in ch||g|||e|be||||||a|ned ||| yat|| ||ite| s|eying|thei||o|t||pme|| |||make||| |n|endim|||i|ge w||||||| t|| ||til|t|| v|||m| ti|e |f||r|m||||||s|e||th|m a| ||l| as|th||| m|n||o|t tali| d|m|n||e| t|er||we
#  ||i|ht||||||t|b||s||ng||he left|an| of the|ca|i|et|in ch||g|||embe||||||a|ned ||||yat|| ||ite| ||eying|thei||o|t||pme|| |||make||| |n|endim|||i|ge |||||||| t|| ||til|t|| v|||m| ti|e |f|br|m||||||s|e||th|m a| ||l| as|th||| m|n||o|t tali| d|m|n||e| t|er||we
#  ||i|ht||||||t|b||s||ng||he left|an| of the|ca|i|et|in ch||g|||embe||||||a|ned ||||yat|| ||ite| ||eying|thei||o|t||pme|| |||make||| |n|endim|||i|ge |||||||| t|| ||til|t|| v|||m| ti|e |f|br|m||||||s|e||th|m a| ||l| as|th||| m|n||o|t tali| d|m|n||e| ther||we
#  ||i|ht||||||t|b||s||ng||he l|ft|an| of the|ca|i|et|in ch||g|||embe||||||a|ned||u||yat|| ||ite| ||eying|thei||o|t||pme|| |||make||| |n|endim|||i|ge |||||||| t|| ||til|t|| v|||m| ti|e |f|br|m||||||s|e||th|m a| ||l| as|th||| m|n||o|t tali| d|m|n||e| there|we
#  ||i|ht |||||t|b||s||ng||he l|ft|an| of the|ca|i|et|in ch||g|||embe||||||a|ned||u||yat|| ||ite| ||eying|thei||o|t||pme|| |||make||| |n|endima||i|ge |||||||| t|| ||til|t|| v|||m| ti|e |f|br|m||||||s|e||th|m a| ||l| as|th||| m|n||o|t tali| d|m|n||e| there|we
#  ||i|ht |||||t|b||s||ng||he l|ft|an| of the|ca|i|et|in ch||g|||embe||||||a|n|d||u||yat|| ||ite| ||eying|thei||o|t||pme|| |||mak|||| |n|endima||i|ge |||||||| t|| ||til|t|| v|||m| ti|e |f|br|m||||||s|e||th|m a| ||l| as|th||| m|n||o|t t|li| d|m|n||e| there|we
#  ||i|ht |||||tab||s||ng||he l|ft|an| of the ca|i|et|in ch||g|||embe||||||a|n|d||u||yat|| ||ite| ||eying|their|o|t||pme|| |||mak|||| |n|endima||i|ge |||||||| t|| ||til|t|| v|||m| ti|e |f br|ml|||||s|e||th|m a| ||l| as|th||| m|n||o|t t|li| d|m|n||e| there|we
#  ||i|ht |||||tab||s||ng||he l|ft|an| of the ca|i|et|in cha|g|||embe||||||a|n|d||u||yat|| ||ite| ||eying|their|o|t||pme|| |||mak|||| |n|endima||i|ge |||||||| t|| ||til|t|| v|||m| ti|e |f br|ml|||||s|e||th|m a| ||l| as|th||| m|n||o|t t|li| d|m|n||e| there|we
#  ||i|ht |||||tab||s||ng||he l|ft|an| of the ca|i|et|in cha|g|||embe||||||a|n|d||u||yat|| ||ite| ||eying|their|o|t||pme|| |||mak|||| |n|endima||i|ge ti|||||| t|| ||til|t|e v|||m| ti|e |f br|ml|||||s|e||th|m a| ||l| as|th||| m|n||o|t t|li| d|m|n||e| there|we
#  ||i|ht |||||tab||s||ng||he l|ft|an| of the ca|i|et|in cha|g|||embe||||||a|n|d||u||yat|| ||it|| ||eying|their|o|t||pme|| |||mak|||| |n|endima||i|ge ti|||||| t|| ||til|t|e v|||m| ti|e |f|br|ml|||||s|e||th|m a| ||l| as|th||| m|n||o|t t|li| d|m|n||e| there|we
#  ||i|ht |||||tab||s||ng||he left|an| of the ca|i|et|in cha|g|||embe||||||a|ned||u||yat|| ||it|| ||eying|their|o|t||pme|| || mak|||| |n|endima||i|ge ti|||f|| t|| ||til|t|e v|||m| ti|e |f|br|ml|||||s|e||th|m a| ||l| as|th||| m|n||o|t t|li| d|m|n||e| there|we
#  ||i|ht |||||tab||s||ng||he left|an| of the ca|i|et|in cha|g|||embe||||||a|ned||u||yat|| ||it|| ||eying|their|o|t||pme|| || mak|||| |n|endima||i|ge ti|||f|| t|| ||til|t|e v|||m| ti|e |f|br|ml|||||s|e||th|m a| ||l| as|th||| m|n||o|t t|li| d|m|n||e| there|we
#  ||i|ht d||||tab||s||ng||he left|an| of the ca|i|et|in cha|g|||embe||||||a|ned||u||yat|| ||ithr |beying|their|o|t||pme|| || mak|||| |n|endima||iage ti|||f|| t|| ||til t|e v|||m| ti|e |f|br|ml|||||s|e||th|m a| ||l| as|th||| m|n||o|t t|li| d|m|n||e| there|we
#  ||i|ht d|s||tabl|s||ng||he left|an| of the ca|i|et|in cha|g|||embe||||||a|ned||u||yat|| ||ithr |beying|their|o|t||pme|| || mak|||| |n|endima||iage ti||||o| t|| ||til t|e v|||m| ti|e |f|br|ml|||||s|e||th|m a| ||l| as|th||| m|n||o|t t||i| dom|n||e| there|we
#  ||i|ht d|s||tabl|s||ng||he left|an| of the ca|i|et|in cha|g|||embe||||||a|ned||u||yat|| ||ithr |beying|their|o|t||pme|| || mak|||| |n|endima||iage ti||||o| t|| ||til t|e v|l|m| ti|e |f|br|ml|||||s|ed|th|m as ||l| as|th||| m|n||o|t t||i| dom|n||e| there|we
#  ||i|ht d|s||tabl|s||ng||he left|an| |f the ca|i|et|in cha|g|||embe||||||a|ned||u||yat|| ||ithr |be|ing|their|o|t||pme|| || mak|||| |n|endima||iage ti||||o| t|| ||til t|e v|l|m| t||e |f|br|ml|||||s|ed|th|m as ||l| as|th||| m|n||o|t t||i| dom|n||e| there|we
#  ||i|ht d|s||tabl|s||ng||he left|an| |f the ca|i|et|in cha|g|||embe||||e|a|ned||u||yat|| ||ithr |be|ing|their|o|t||pme|| || mak|||| |n|endima||iage ti||||o| t|| ||til t|e v|l|m| t||e |f|br|ml|||||s|ed|th|m as ||l| as|th||| m|n||o|t t||i| dom|n||e| there|we
#  |ei|ht d|s||tabl|s||ng||he left|an| |f the ca|i|et|in cha|g|||embe||||e|ained |u||yat|| ||ithr |be|ing|their|o|t||pme|t||| mak|||| |n|endima||iage ti||||o| t|| u|til t|e v|l|m| t||e |f|br|ml|||||s|ed|th|m a| ||l| as|th||| m|n||o|t t||i| dom|n||e| th|re|we
#  |ei|ht d|s||tabl|s||ng||he left|an| |f the ca|i|et|in cha|g|||embe||||e|ained su||yat|| ||ithr |be|ing|their|o|t||pme|t || mak|||| |n|endima||iage ti||||o| t|| u|til t|e v|l|m| t||e |f|br|ml|||||s|ed|th|m a| ||l| as|thr|| m|n||o|t t||i| dom|na|e| th|re|we
#  |ei|ht d|s||tabl|s||ng||he left|an| |f the ca|i|et|in cha|g|||embe||||e|ained su||yat|| ||ith| |be|ing|their|o|t||pme|t || mak|||n |n|endima||iage ti||||o| t|| u|til t|e v|l|m| t||e |f|br|ml|||||s|ed|th|m a| ||l| as|thr|| m|n||o|t t||i| dom|na|e| th|re|we
#  |ei|ht d|s||tabl|s||ng||he left|an| |f the cabi|et|in cha|g|||embe||||e|ained su||yat|| ||ith| |be|ing|their|o|t||pme|t |o mak|||n |n|endimar|iage ti||||o| t|| u|til t|e v|l|m| t||e |f|br|ml|y|||s|ed|th|m a| ||l| as|thr|| m|n||o|t t||i| dom|na|e| th|re|we
#  |ei|ht d|se|tabl|s||ng|the left|an| |f|the cabi|et|in cha|g| |embe||||e|ained su||yat|| ||ith| |be|ing|their|o|t||pme|t |o mak|||n |n|endimar|iage ti||||o| t|| u|til t|e v|l|m| t||e |f|br|ml|y|||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|s|ing|the left|an| |f|the cabi|et|in cha|g| |embe||||e|ained su||yatt| ||ith| |be|ing|their|o|t||pme|t |o mak|||n |n|endimar|iage ti||||o| t|| u|til t|e v|l|m| t||e |f|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|shing|the left|an| |f|the cabi|et|in cha|g| |embe||||e|ained su||yatt| |mith| |be|ing|their|o|t||pme|t |o mak|||n |n|endimar|iage|ti||||o| t|| u|til t|e v|l|m| t||e |f|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|shing|the left|an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatt| |mith| |be|ing|their|o|t||pme|t |o mak|||n |n|endimar|iage|ti|||ro| t|| u|til t|e v|l|m| t||e |f|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|shing|the left|an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatt| smith| |be|ing|their|o|t||pme|t |o mak||an |n|endimar|iage|ti|||ro| t|| u|til t|e v|l|m| t||e |f|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|shing|the left|an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatt| smith| |be|ing|their|o|t||pme|t |o mak||an |n|endimar|iage|ti|||ro| t|| u|til t|e v|l|m| t||e of|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|shing|the left|an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatt| smit|| |be|ing|their|o|t||pme|t |o make an |n|endimar|iage ti|||ro| t|| u|til t|e v|l|m| t||e of|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|shing|the left|an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatte smit|| |be|ing|their|out||pme|t |o make an |n|endimar|iage ti|||ro| t|| u|til t|e v|l|m| t||e of|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|shing|the |eft|an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatte smit|| |be|ing|their|out||pment |o make an |n|endimar|iage ti|||ro| t|| u|til t|e v|l|m| t||e of|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re|we
#  |ei|ht d|sestabl|shing|the |eft an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatte smit|| |be|ing|their|out||pment |o make an |n|endimar|iage ti|||ro| t|| u|til t|e v|l|m| t||e of|br|ml|y ||s|ed|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re we
#  |ei|ht d|sestabl|shing|the |eft an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatte smit||||be|ing|their|out||pment |o make an |n|endimar|iage ti|||ro| t|| u|til t|e v|l|m| t||e of|br|ml|y ||s||d|th|m a| ||l| as thr|| m|n||o|t t|||| dom|na|e| th|re we
#  |ei|ht d|sestabl|shing|the |eft an| |f|the cabinet|in cha|g| |embe||||e|ained su||yatte smit|s||be|ing|their|out||pment |o make an |n|endimar|iage ti|||ro| t|| u|til t|e vol|m| t||e of|br|ml|y ||s||d|th|m a| ||l| as thr|| m|n||o|t t|||e dom|na|e| th|re we
#  |ei|ht d|sestabl|shing|the |eft an| |f|the cabinet|in cha|g| |ember|||e|ained su||yatte smit|s||be|ing|their|ou|||pmen| |o make an |n|endimar|iage ti|||ro| t|| u|til t|e vol|m| t||e of|br|ml|y ||s||d|th|m a| ||l| as thr|| m|n||o|t t|||e dom|na|e| th|re we
#  |ei|ht d|sestabl|shing|the |eft an| |f|the cabinet|in cha|g| |ember|||e|ained su||yatte smit|s |be|ing|their|ou|||pmen| |o make an |n|endimar|iage ti| |rot t|| u|til t|e vol|m| t||e of|br|ml|y ||s||d|th|m a| ||l| as thr|| m|n||o|t t|||e dom|nate| th|re we
#  |ei|ht d|sestabl||hing|the |eft and |f|the cabinet|in cha|g| |ember|||e|ained su||yatte smit|s |be|ing|their|ou||ipmen| |o make an |n|endimar|iage ti| |rot t|| u|til t|e vol|m| t||e of|br|ml|y ||s||d|th|m a| ||l| as thr|| m|n||o|t t|||e dom|nate| th|re we
#  |ei|ht d|sestabl||hing|the left and |f|the cabinet|in cha|g| |ember|||e|ained sur|yatte smit|s |be|ing|their|ou||ipmen| |o make an |n|endimar|iage ti| prot t|| u|til t|e vol|m| t||e of|br|ml|y ||s||d|them a| ||l| as thr|| m|n||o|t t|||e dom|nate| there we
#  |ei|ht d|sestabl||hing|the left and |f|the cabinet|in cha|g| |ember|||e|ained sur|yatte smit|s |be|ing|their|ou||ipmen| |o make an||n|endimar|iage ti| prot t|| u|til t|e vol|m| t||e of|br|ml|y ||s||d|them a| ||l| as thre| m|n||o|t t|||e dom|nate| there we
#  |ei|ht d|sestabl||hing|the left and |f the cabinet|in cha|g| |ember|||e|ained sur|yatte smit|s |be|ing|their|ou||ipmen| |o make an||ntendimar|iage ti| prot t|| u|til t|e vol|m| t||e of|broml|y ||s||d|them a| ||l| as thre| m|n|po|t to |e dom|nate| there we
#  |ei|ht d|sestabl||hing|the left and |f the cabinet|in cha|g| |ember|||e|ained sur|yatte smit|s |be|ing|their|ou||ipmen| |o make an||ntendimar|iage ti| prot t|| u|til t|e vol|m| t||e of|broml|y ||s||d|them a| |el| as thre| m|n|po|t to |e dom|nate| th|re we
#  |ei|ht d|sestabl||hing the left and |f the cabinet|in cha|g| |ember|||e|ained sur|yatte smit|s |be|ing|their|ou||ipmen| |o make an||ntendimar|iage ti| prot t|| u|til t|e vol|m| t||e of|broml|y ||s||d|them a| |el| as thre| m|n|po|t to |e dom|nate| th|re we
#  |ei|ht d|sestabl||hing the left and |f the cabin|t|in cha|g| |ember|||e|ained sur|yatte smiths |be|ing|their|ou||ipmen| |o make an |ntendimar|iage ti| prot t|| u|til t|e vol|m| t||e of|broml|y ||s||d|them as |el| as thre| m|n|po|t to |e dominate| |h|re we
#  |ei|ht d|sestabl||hing the left and |f the cabinet|in cha|ge |ember|||e|ained sur yatte smiths |be|ing|their|ou||ipmen| |o make an |ntendimar|iage ti| prot t|| u|til t|e vol|m| t||e of|bromley ||s||d|them as |el| as thre| m|n|po|t to |e dominated |h|re we
#  |ei|ht d|sestabl|shing the left and |f th| cabinet|in cha|ge |ember|||e|ained sur yatte smiths||be|ing|their|ou||ipmen| |o make an |ntendimar|iage ti| prot to| until t|e vol|m| t||e of|bromley ||s||d|them as |ell as thre| m|n|po|t to |e d|minated th|re we
#  |ei|ht d|sestabl|shing the left and |f th| cabinet|in cha|ge |ember|||e|ained sur yatte smiths |be|ing|their|ou||ipmen| |o make an |ntendimar|iage ti| prot to| until t|e vol|m| t||e of|bromley ||shed|them as |ell as thre| men|post to |e d|minated th|re we
#  |ei|ht d|sestabl|shing the left and of th| cabinet|in cha|ge |ember|||e|ained sur yatte smiths |be|ing|their|ou||ipmen| |o make |n |ntendimar|iage ti| prot to| until t|e vol|m| t||e of bromley ||shed|them as |ell as thre| men|p|st to |e d|minated th|re we
#  |ei|ht d|sestabl|shing the left and of th| cabinet|in cha|ge |ember|||emained sur yatte smiths |be|ing|their|ou||ipmen| |o make |n |ntendimar|iage ti| prot to| until the vol|m| t|le of bromley ||shed|them as |ell as thre| men|p|st to |e d|minated th|re we
#  |ei|ht d|sestabl|shing the left|and of th| cabinet|in cha|ge |ember|||emained sur yatte smiths |be|ing|their|ou||ipmen| |o make |n |ntendimar|iage ti| prot to| until the vol|m| t|le of bromley ||shed|them as |ell as thre| men|p|st to |e d|minated th|re we
#  wei|ht d|sestablishing the left|and of th| cabinet|in cha|ge member| |emained sur yatte smiths |be|ing|their|ou||ipmen| |o make |n |ntendimar|iage ti| prot to| until the vol|m| t|le of bromley ||shed|them as |ell as thre| men p|st to |e d|minated th|re we
#  wei|ht d|sestablishing the left|and of th| cabinet|in c|a|ge memb|r| |emained sur yatte smiths |be|ing|their|ou|iipmen| |o make |n |ntendimar|iage ti| prot to| until the v|l|m| t|le of |romley ||shed|them as |ell |s thre| men p|st to |e d|minated th|re we
#  wei|ht d|sestablishing the left|and of th| cabinet|in c|a|ge memb|r| |emained sur yatte smiths |be|ing|their|ou|iipmen| |o make |n |ntendimar|iage ti| prot to| until the v|l|me t|le of |romley ||shed|them as |ell |s thre| men past to be d|minated th|re we
#  wei|ht d|sestablishing the left|and of th| cabinet|in c|a|ge memb|rs |emained sur yatte smiths |be|ing|their|ou|iipmen| |o make |n |ntendimar|iage ti| pr|t to| until the v|l|me t|le of |romley ||shed|them as |ell |s thre| men past to be d|minated th|re we
#  wei|ht d|sestablishing the left and of th| cabinet|in c|arge memb|rs remained sur yatte smiths |be|ing|their|ou|iipmen| |o make |n |ntendimar|iage ti| pr|t to| until the v|lume t|le of |romley ||shed|them as |ell |s thre| men past to be d|minated th|re we
#  wei|ht d|sestablishing the left and of t|| cabinet|in c|arge memb|rs remained sur yatte smiths |be|ing|their|ou|iipmen| |o make |n |ntendimar|iage ti| pr|t to| until the volume t|le of |romley ||shed|them as |ell |s thre| men past to be d|minated th|re we
#  wei|ht d|sestablishing the left and of t|| cabinet in c|arge memb|rs remained sur yatte smiths |be|ing|their|ou|iipmen| |o make |n intendimar|iage ti| pr|t too until the volume t|le of |romley ||shed|them as |ell |s thre| men past to be d|minated th|re we
#  wei|ht d|sestablishing the left and of t|| cabinet in c|arge memb|rs remained sur yatte smiths |be|ing|their ou|iipmen| |o make |n intendimar|iage ti| pr|t too until the volume t|le of |romley ||shed|them as |ell as thre| men past to be d|minated there we
#  wei|ht d|sestablishing the left and of th| cabinet in c|arge memb|rs remained sur yatte smiths |be|ing|their ou|iipmen| |o make |n intendimar|iage ti| pr|t too until the volume t|le of |romley p|shed|them as |ell as three men past to be d|minated there we
#  wei|ht d|sestablishing the left and of th| cabinet in c|arge memb|rs rem|ined sur yatte smiths |be|ing|their outiipmen| |o make |n intendimar|iage tim pr|t too until the volume t|le of |romley p|shed them as |ell as three men past to be d|minated there we
#  wei|ht d|sestablishing the left and of th| cabinet in c|arge members rem|ined sur yatte smiths |be|ing|their outiipmen| |o make |n intendimar|iage tim pr|t too until the volume tale of |romley p|shed them as |ell as three men past to be d|minated there we
#  wei|ht d|sestablishing the left and of th| cabinet in c|arge members rem|ined sur yatte smiths |be|ing|their outiipmen| |o make |n intendimar|iage tim pr|t too until the volume tale of |romley p|shed them as |ell as three men past to be d|minated there we
#  wei|ht d|sestablishing the left and of th| cabinet in charge members rem|ined sur yatte smiths |be|ing|their outiipmen| |o make |n intendimar|iage tim pr|t too until the volume tale of |romley p|shed them as |ell as three men past to be d|minated there we
#  wei|ht d|sestablishing the left and of the cabinet in charge members rem|ined sur yatte smiths obe||ng|their outiipmen| |o make |n intendimar|iage tim prat too until the volume tale of |romley pushed them as |ell as three men past to be d|minated there we
#  wei|ht d|sestablishing the left and of the cabinet in charge members rem|ined sur yatte smiths obe||ng their outiipment to make |n intendimar|iage tim prat too until the volume tale of |romley pushed them as well as three men past to be d|minated there we
#  wei|ht d|sestablishing the left and of the cabinet in charge members remained sur yatte smiths obe||ng their outiipment to make |n intendimar|iage tim prat too until the volume tale of |romley pushed them as well as three men past to be d|minated there we
#  wei|ht d|sestablishing the left and of the cabinet in charge members remained sur yatte smiths obe||ng their outiipment to make |n intendimar|iage tim prat too until the volume tale of |romley pushed them as well as three men past to be d|minated there we
#  wei|ht disestablishing the left and of the cabinet in charge members remained sur yatte smiths obe||ng their outiipment to make |n intendimar|iage tim prat too until th| volume tale of |romley pushed them as well as three men past to be d|minated there we
#  weight disestablishing the left and of the cabinet in charge members remained sur yatte smiths obe||ng their outiipment to make |n intendimar|iage tim prat too until th| volume tale of bromley pushed them as well as three men past to be d|minated there we
#  weight disestablishing the left and of the cabinet in char|e members remained sur yatte smiths obey|ng their outiipment to make |n intendimar|iage tim prat too until the volume tale of bromley pushed them as well as three men past to be d|minat|d there we
#  weight disestablishing the left and of the cabinet in char|e members remained sur yatte smiths obey|ng their outiipment to make |n intendimar|iage tim prat too until the volume tale of bromley pushed them as well as three men past to be d|minat|d there we
#  weight disestablishing the left and of the cabinet in charge members remained sur yatte smiths obeying their outiipment |o make |n intendimar|iage tim prat too until the volume tale of bromley pushed them as well as three men past to be d|min|t|d there we
#  weight disestablishing the left and of the cabinet in charge members remained sur yatte smiths obeying their outiipment |o make |n intendimarriage tim prat too until the volume tale of bromley pushed them as well as three men past to be d|minat|d there we
# |weight disestablishing the left and of the cabinet in charge members remained sur yatte smiths obeying their outiipment |o make || intendimarriage |im prat too until the volume tale of bromley pushed them as well as three men past |o be d|minat|d there we
#  weight disestablishing the left and of the cabinet in charge members remained sur yatte smiths obeying their outiipment to make io intendimarriage tim prat too until the volume tale of bromley pushed them as well as three men past to be dominated there we
#  weight disestablishing the left and of the cabinet in ch|rge members remained sur yatte smiths obeying their outiipment to make io intendimarriage tim prat too unti| the volume tale of bromley pushed them as well as three men past to be dominated there we

# %%
# concated = " ".join(texts)
    
# generated_words = concated.split()
# # len(texts), len(generated_words)

# # check if generated words are in vocab
# s = 0
# for word in tqdm(generated_words):
#     if word in vocab:
#         s += 1

# print(s / len(generated_words))

# %%
from multiprocessing import Pool

concated = " ".join(texts)
    
generated_words = concated.split()

cpus=16
chunk_size = len(generated_words) // cpus + 1

def check_word_in_vocab(i):
    s = 0
    for word in tqdm(generated_words[i:i + chunk_size]):
        if word in vocab:
            s += 1
    return s
# Use a pool of workers to check the words in parallel

with Pool(cpus) as p:
    results = p.map(check_word_in_vocab,  range(0, len(generated_words), chunk_size))

print(sum(results) / len(generated_words))
# Out:
# /home/yixiuz/miniconda3/lib/python3.12/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /home/yixiuz/miniconda3/lib/python3.12/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 100%|██████████| 1469/1469 [00:06<00:00, 224.68it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 234.80it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 225.66it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 218.51it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 225.12it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 225.49it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 220.87it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 219.85it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 217.88it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 227.82it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 224.73it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 221.23it/s]
# 100%|██████████| 1464/1464 [00:06<00:00, 226.18it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 212.87it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 217.31it/s]
# 100%|██████████| 1469/1469 [00:06<00:00, 211.71it/s]
# 0.8584195072130729

# %%
# workdir = "gs://maskdiff/SIC/text8_sic_fixed_32_steps"
# Informed: 0.8630749014454665
# Informed (256 steps): 0.980857811674092
# Ancestral (256 steps): ~0.85

# %%
# workdir = "gs://maskdiff/SIC/text8_sic_fixed"
# Ancestral: 0.7536640360766629
# Uninformed: 0.7263929743786502
# Informed: 0.9155978150920494

# %%
# import pickle 
# with open('/home/yixiuz/baseline_acc.pkl', 'rb') as f:
#     baseline_acc = pickle.load(f)
# baseline_acc
# Out:
# {16: 0.7461044912923923,
#  32: 0.8284363094977449,
#  64: 0.8732092941998603,
#  128: 0.89815259641001,
#  256: 0.9017050711547782}
