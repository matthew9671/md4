# %%
import pickle
from multiprocessing import Pool

with open("/root/md4/data_dir/text8/text8_vocab.pkl", "rb") as f:
    vocab = pickle.load(f)

# %%
def post_process(texts):
    concated = " ".join(texts)
    generated_words = concated.split()
    s = 0
    for word in generated_words:
        if word in vocab:
            s += len(word) + 1
    return s / len(concated)

# %%
with open("/root/md4/data_dir/text8/baseline_generations.pkl", "rb") as f:
    results_dict = pickle.load(f)
with Pool(64) as p:
    acc_dict = dict(
        zip(results_dict.keys(), p.map(post_process, results_dict.values()))
    )
with open(
    "/root/md4/data_dir/text8/baseline_generations_acc_new.pkl", "wb"
) as f:
    pickle.dump(acc_dict, f)

# %%
with open("/root/md4/data_dir/text8/informed_corrector_generations_16.pkl", "rb") as f:
    results_dict = pickle.load(f)
with Pool(64) as p:
    acc_dict = dict(
        zip(results_dict.keys(), p.map(post_process, results_dict.values()))
    )

# %%
with open(
    "/root/md4/data_dir/text8/informed_corrector_generations_16_acc_new.pkl", "wb"
) as f:
    pickle.dump(acc_dict, f)

# %%
meta_dict = {}
timestep_list = [16, 32, 64, 128, 256]
for timesteps in timestep_list:
    with open(
        f"/root/md4/data_dir/text8/informed_corrector_generations_{timesteps}_acc_new.pkl",
        "rb",
    ) as f:
        results_dict = pickle.load(f)
    meta_dict[timesteps] = results_dict

# %%
for timesteps in timestep_list:
    meta_dict[timesteps] = max(meta_dict[timesteps].values())

# %%
with open(
    "/root/md4/data_dir/text8/informed_corrector_generations_acc_max_new.pkl", "wb"
) as f:
    pickle.dump(meta_dict, f)

# %%
with open("/root/md4/data_dir/text8/uninformed_corrector_generations.pkl", "rb") as f:
    results_dict = pickle.load(f)

with Pool(64) as p:
    acc_dict = dict(
        zip(results_dict.keys(), p.map(post_process, results_dict.values()))
    )

with open(
    "/root/md4/data_dir/text8/uninformed_corrector_generations_acc_new.pkl", "wb"
) as f:
    pickle.dump(acc_dict, f)

# %%
timestep_list = [16, 32, 64, 128, 256]

# %%
new_dict = {}
for timesteps in timestep_list:
    new_dict[timesteps] = max(
        [acc_dict[timesteps, step_size] for step_size in [0.5, 1.0, 2.0, 4.0]]
    )
with open(
    "/root/md4/data_dir/text8/uninformed_corrector_generations_acc_max_new.pkl", "wb"
) as f:
    pickle.dump(new_dict, f)

# %%
with open("/root/md4/data_dir/text8/maskgit_generations.pkl", "rb") as f:
    results_dict = pickle.load(f)

with Pool(64) as p:
    acc_dict = dict(
        zip(results_dict.keys(), p.map(post_process, results_dict.values()))
    )

with open("/root/md4/data_dir/text8/maskgit_generations_acc_new.pkl", "wb") as f:
    pickle.dump(acc_dict, f)

# %%
timestep_list = [16, 32, 64, 128, 256]
for timesteps in timestep_list:
    new_dict[timesteps] = max(
        [
            acc_dict[timesteps, tem]
            for tem in [0.5, 1.0, 2.0, 4.0, 8.0, 10.0, 12.0, 16.0, 20.0, 40.0]
        ]
    )
with open("/root/md4/data_dir/text8/maskgit_generations_acc_max_new.pkl", "wb") as f:
    pickle.dump(new_dict, f)

# %%
# get all four acc_max
import pickle

meta_results_dict = {}
with open("/root/md4/data_dir/text8/maskgit_generations_acc_max_new.pkl", "rb") as f:
    meta_results_dict["maskgit"] = pickle.load(f)
with open(
    "/root/md4/data_dir/text8/informed_corrector_generations_acc_max_new.pkl", "rb"
) as f:
    meta_results_dict["informed_corrector"] = pickle.load(f)
with open(
    "/root/md4/data_dir/text8/uninformed_corrector_generations_acc_max_new.pkl", "rb"
) as f:
    meta_results_dict["uninformed_corrector"] = pickle.load(f)
with open("/root/md4/data_dir/text8/baseline_generations_acc_new.pkl", "rb") as f:
    meta_results_dict["baseline"] = pickle.load(f)

# %%
from matplotlib import pyplot as plt
import numpy as np

timestep_list = [16, 32, 64, 128, 256]
for key, value in meta_results_dict.items():
    plt.plot(
        timestep_list,
        1 - np.array([value[timestep] for timestep in timestep_list]),
        label=key,
    )
plt.legend()
plt.ylabel("Error Rate")
plt.xlabel("NFEs")
plt.grid()

# %%
with open(
    "/root/md4/data_dir/text8/informed_corrector_generations_32_acc.pkl", "rb"
) as f:
    results_dict = pickle.load(f)

# %%
results_dict
# Out:
# {(1, 0.1): 0.904065390406539,
#  (1, 1.0): 0.8800309597523219,
#  (1, 2.0): 0.8369433897134967,
#  (1, 10.0): 0.772189863513866,
#  (1, 1000.0): 0.7615160856162897,
#  (2, 0.1): 0.9350966690958975,
#  (2, 1.0): 0.9271560025679435,
#  (2, 2.0): 0.8891309920533197,
#  (2, 10.0): 0.798390237569778,
#  (2, 1000.0): 0.7821040322231365,
#  (4, 0.1): 0.9580700506339708,
#  (4, 1.0): 0.7615160856162897,
#  (4, 2.0): 0.9347062853228293,
#  (4, 10.0): 0.813671587514611,
#  (4, 1000.0): 0.7821040322231365,
#  (8, 0.1): 0.9566152597402597,
#  (8, 1.0): 0.9532112023583912,
#  (8, 2.0): 0.9461368277739959,
#  (8, 10.0): 0.8407232027550581,
#  (8, 1000.0): 0.8010197411426331,
#  (16, 0.1): 0.9349056230461794,
#  (16, 1.0): 0.933620159803319,
#  (16, 2.0): 0.9360852197070573,
#  (16, 10.0): 0.8419837537409149,
#  (16, 1000.0): 0.7876209398756047}

# %%
with open(
    "/root/md4/data_dir/text8/uninformed_corrector_generations_acc.pkl", "rb"
) as f:
    results_dict = pickle.load(f)

x_list = []
y_list = []
value_list = []
for key, value in results_dict.items():
    x_list.append(key[0])
    y_list.append(key[1])
    value_list.append(value)

# plot those with the sample x values and plot curves with different y values
x_list = np.array(x_list)
y_list = np.array(y_list)
value_list = np.array(value_list)

for x in set(x_list):
    plt.plot(y_list[x_list == x], 1 - value_list[x_list == x], label=f"{x}")
plt.legend(title="Timesteps")
plt.xlabel("Step Size")
plt.ylabel("Error Rate")
plt.grid()
plt.show()

# %%
with open("/root/md4/data_dir/text8/uninformed_corrector_generations.pkl", "rb") as f:
    results_dict = pickle.load(f)

# %%
results_dict.keys()
# Out:
# dict_keys([(16, 0.5), (32, 0.5), (64, 0.5), (128, 0.5), (256, 0.5), (16, 1.0), (32, 1.0), (64, 1.0), (128, 1.0), (256, 1.0), (16, 2.0), (32, 2.0), (64, 2.0), (128, 2.0), (256, 2.0), (16, 4.0), (32, 4.0), (64, 4.0), (128, 4.0), (256, 4.0)])

# %%
texts = results_dict[16, 0.5]

# %%
concated = " ".join(texts)
generated_words = concated.split()
s = 0
for word in generated_words:
    if word in vocab:
        s += len(word) + 1
s / len(concated)
# Out:
# 0.5581952075876063

# %%
"te" in vocab
# Out:
# True

# %%
concated
# Out:
# 'e  ujbai uds bd te en hee zah srah saalyam fearna katrina ichaj cam ha m ez   eola venis  i a hinny canh bei breef i  h daice giwi he thee hawa h a teak h naa a h s nga raon horu r inut kai or i en ko ska a asika s er i le en erya n srinda ch i n ger hun n   a seleprinter  arem zwanzal onych b byle nmijczeszow  szes cz poma shamnoca  ievocegar s a baznar  hanes k kranigm rd sz n ndki tefj ndo p  taakortat tuysiak mc zarnigzad yc regyh z cz sdw rda abe wa  lae im ci ce ca ja skompazary szawke zaradnj uk kongo a saamin s amer sonsredanoth bekanertis s rti a  er  e va na sigra do bria va pas bru malakta a kalaka ne kainits  vadversa minti a pandika husskai ana ny ulena prinsert pocneistein kaatan malakaka musna mashuja maetuka hsn dabyk nisv r marvanch u naytava  arkunnan vaz roan roan stania brontill uma tm crosnia ru rt a c  ije taang  i jlac ono  imiop antsura a usa ude tanwest udaui auaash i anon anta arittenau  niwamecenyaoi malovecuna herewolmarantonia kin wastva tsia ts na a ri i a iantsiga a eec sa ro anian a ipeilanus lombo m mbi o helno chsko k sko  ltar sailike iera homa lima mokotot bo so kokomurana sela slense so soola slope goran e slava bo manna voluole ma sa  i  ula ja kopol  estu erroz tu  updiauta dedurantwa do het aber kuna utaddo s a san bha ara i       ait arom n shtail nstabayaeamre tsigam oonjun tatvac kap tiray san ad mal yorrog titkun yom d na  o aoo sauro souta  n ma aon mas owe ow same samelti zems sama sutat t n hyoaknam zen damin dar serola gun howitzer zarmen von domengasten hometown akser n vilay n jol al n kolm nerv indir s aguine proven star winowa  obrazhd n svart  el bilo   mel ka  s zf larll em slemo ku prakshri mp kohanyut oeli me start vand al tt u vudmae kuli praksh v as p sk in dieve ilai iloi ze v ze p vel oe     ere mrihnagwanedm  apechea  adi reei s m tavarsnaga sam ra s   ri s tar a de   wr ar palri mi soubili  uuirr o er ke  a     a v  ein leijsts edta ha specurum ha li a drogue h ren t tengg d hi iche fart tull kahi tu hajj kam yz kam ne er sal  und de at  ee i grok a i i r ey    f you s av e do guar  otbo skal p a t a ca re t ilayoongormdja se tengu had thaw l groe   r na  o r m y ni seie  d ri r d o r hel i ta ad i m me ne k hum i  nar s p ar n bl ringo fu ea   i dli ting e l s schala oil tabyru le i sadd sh i  i  the imhla ro  brella cherc istrhaille ogine bhaaland ya mbalan   ang c chl  mn ha ba ma goaa  nti bu cong pa hops pa alas rlmaor palanhhtha a bo ha la  aila macha tirmesh ma aa malla r a ala bamari bama blach malhelm mhlambumruo thaa  ae ra a dia diama na mal urnu malri  mon  pniroai kari  a pi mwei mu u ni mo tru phi ongi attu tawar mi nga kleha nu m nas her i bega ti h mon i  gu mama gu r mi gm h ke oh moei au ps vertegas ha ta im ortho   och hoggie ewa eu nowargen noma ei  nie mos os a  ieyeroons e a ei as i s eri s bs  ll iana frugedis kaikan  i  ana kais  kaiaa juncen goruni ud rska bosara achkolingaa mcgath hinne ko ngaad   aarunsap kaleaba ngamaele ga ngelapechin libya kwara red sharaahaasa ta kai menemeaai k dvalana an houa  mikven voo trou troandis kan manama mru a  af ad nnn p nema n  nna radi ac nai men u phni  nem ri ko  tl tana tl   incero elpuinsetil is r kojeshi dior kun wana tima  nto a va isslee esas ksos lv bofead csoiks taptenaartergygi naj s ple  sae kam ns as tag ju tavoor n pghvai beios kaos pok el railr e tae summa    kem an wceyz tape  a porers are biznan giae szemosy iaavbryny hellir s uniq s arz  roke a biskie elet u nr d ey sak szeckien ramy helvorsud minsk pred zak chz eat ne sch pazgan ki zaraa zeriz s pomtrzlyvznin zandyrov a wedow van zquky destr   min d a  cei b a dreghdram nei mpn vad sp herem ngl nol n s pt s pt dann aelian the sep ius ag ah  hef  omipv  oun sectament nation syriamam laos labs lag m lagis nee m nan aa aaoi j deingsam nec nagst an aa aara ia ni   i finitil ni holy  e gclyte not pa  a chard tagma   a by  e gsakba bg  g heb everciz onam tv iciza trg nral d j na i c d n ldaosta mt aromapq ctldw t r a f ag rh ad frag digs egg  ...

# %%
generated_words
# Out:
# ['our',
#  'e',
#  'co',
#  'te',
#  'e',
#  's',
#  'ae',
#  'ee',
#  'ly',
#  'ae',
#  'he',
#  'ee',
#  'ly',
#  'ae',
#  'iee',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'an',
#  'e',
#  'an',
#  'and',
#  'te',
#  'e',
#  'in',
#  'iee',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'ment',
#  'r',
#  'men',
#  'iee',
#  'of',
#  'the',
#  'he',
#  'e',
#  'on',
#  'our',
#  'e',
#  'in',
#  'e',
#  't',
#  'our',
#  'e',
#  'ere',
#  'iee',
#  'tee',
#  'our',
#  'he',
#  'e',
#  'the',
#  'he',
#  'e',
#  'in',
#  'e',
#  'ing',
#  't',
#  'ee',
#  'an',
#  'ingh',
#  'e',
#  'in',
#  'e',
#  'ine',
#  'tee',
#  'ing',
#  't',
#  'e',
#  'ine',
#  'tee',
#  'he',
#  'e',
#  'wo',
#  'e',
#  'he',
#  'e',
#  'an',
#  'e',
#  'iee',
#  'tee',
#  'e',
#  'external',
#  'i',
#  's',
#  'e',
#  'in',
#  'e',
#  'e',
#  'on',
#  'e',
#  'our',
#  'e',
#  's',
#  'ee',
#  'and',
#  'to',
#  'e',
#  'an',
#  'e',
#  'an',
#  'an',
#  'iee',
#  'tee',
#  'e',
#  'on',
#  'e',
#  's',
#  'ae',
#  'and',
#  'te',
#  'o',
#  'k',
#  'e',
#  'in',
#  'e',
#  'e',
#  'be',
#  'ine',
#  'tee',
#  'and',
#  'te',
#  'iee',
#  'tee',
#  'ine',
#  'tee',
#  'e',
#  's',
#  'ae',
#  'ing',
#  't',
#  'e',
#  'an',
#  'he',
#  'e',
#  's',
#  'ae',
#  'iee',
#  'tee',
#  'e',
#  'an',
#  'o',
#  'k',
#  'and',
#  'at',
#  'our',
#  'e',
#  'the',
#  'e',
#  'on',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'e',
#  'in',
#  'e',
#  'he',
#  'ie',
#  'our',
#  'e',
#  'in',
#  'iee',
#  'tee',
#  'our',
#  'ine',
#  'tee',
#  'our',
#  'e',
#  'wo',
#  'iee',
#  'tee',
#  'the',
#  'mas',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'and',
#  'te',
#  'he',
#  'e',
#  'ing',
#  't',
#  'o',
#  'in',
#  'e',
#  'ine',
#  'tee',
#  'e',
#  'the',
#  'ad',
#  'n',
#  'e',
#  'on',
#  'ne',
#  'in',
#  'e',
#  't',
#  'ine',
#  'tee',
#  'ine',
#  'tee',
#  'ine',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'e',
#  'ere',
#  'iee',
#  'tee',
#  'and',
#  'te',
#  'e',
#  'in',
#  'e',
#  'an',
#  'e',
#  'co',
#  'oee',
#  'in',
#  'e',
#  'e',
#  'in',
#  'and',
#  'te',
#  'al',
#  'e',
#  'in',
#  'e',
#  'e',
#  'on',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'e',
#  'on',
#  'e',
#  'an',
#  'e',
#  'joct',
#  'e',
#  'the',
#  'e',
#  'e',
#  'e',
#  'an',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'iee',
#  'tee',
#  'iee',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'e',
#  'ere',
#  'our',
#  'a',
#  'ke',
#  'an',
#  'e',
#  'the',
#  'ee',
#  'e',
#  'ment',
#  'iee',
#  'tee',
#  'e',
#  'be',
#  'e',
#  'in',
#  'e',
#  'an',
#  'ine',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'ine',
#  'tee',
#  'he',
#  'ie',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'e',
#  'on',
#  'iee',
#  'tee',
#  'iee',
#  'tee',
#  'e',
#  'ee',
#  'f',
#  're',
#  'e',
#  'an',
#  'equent',
#  'e',
#  'five',
#  'e',
#  'e',
#  'the',
#  'ee',
#  'e',
#  'an',
#  'e',
#  'perte',
#  'e',
#  's',
#  'ae',
#  'e',
#  's',
#  'ae',
#  'ale',
#  'e',
#  'on',
#  'e',
#  'in',
#  'ee',
#  'ine',
#  'tiee',
#  'iee',
#  'tee',
#  'e',
#  's',
#  'ae',
#  'e',
#  'an',
#  'e',
#  'the',
#  'e',
#  'e',
#  'an',
#  'e',
#  'ine',
#  'zero',
#  'zero',
#  'zero',
#  'e',
#  'iee',
#  'tee',
#  'an',
#  'e',
#  'ment',
#  'e',
#  'perte',
#  'he',
#  'oe',
#  'y',
#  'ung',
#  'ing',
#  't',
#  'e',
#  'ch',
#  'an',
#  'e',
#  'an',
#  'e',
#  's',
#  'ae',
#  'e',
#  'the',
#  'e',
#  'co',
#  'te',
#  'e',
#  'on',
#  'e',
#  'ere',
#  'an',
#  'e',
#  'ine',
#  'te',
#  're',
#  'e',
#  'ee',
#  'tee',
#  'ee',
#  'ly',
#  'ae',
#  'and',
#  'te',
#  'one',
#  'eight',
#  'sir',
#  'and',
#  'tion',
#  'ale',
#  'e',
#  'an',
#  'e',
#  'joct',
#  'e',
#  'enght',
#  'e',
#  's',
#  'e',
#  'ee',
#  'ly',
#  'ae',
#  'our',
#  'e',
#  'ere',
#  'and',
#  'te',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'e',
#  'an',
#  're',
#  'ne',
#  'tee',
#  'our',
#  'ee',
#  'ly',
#  'ae',
#  'he',
#  'ad',
#  'n',
#  'e',
#  'the',
#  'e',
#  'ane',
#  'ne',
#  'toe',
#  'e',
#  'an',
#  'ee',
#  'be',
#  'e',
#  'an',
#  'e',
#  'ment',
#  'and',
#  'te',
#  'e',
#  'an',
#  'e',
#  'ment',
#  'e',
#  'in',
#  'e',
#  'on',
#  'e',
#  'ine',
#  'teee',
#  'iee',
#  'tee',
#  'e',
#  'ment',
#  'e',
#  'perte',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'our',
#  'ale',
#  'e',
#  'in',
#  'e',
#  'e',
#  'ment',
#  'os',
#  'toe',
#  'i',
#  'e',
#  's',
#  'ane',
#  'tee',
#  'e',
#  'th',
#  's',
#  'ae',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'ate',
#  'nal',
#  'e',
#  'ment',
#  'e',
#  'pert',
#  'ere',
#  'e',
#  'ere',
#  'e',
#  'one',
#  'ine',
#  'eight',
#  'e',
#  'an',
#  'e',
#  'ine',
#  'tee',
#  'he',
#  'e',
#  'mene',
#  'ane',
#  'tee',
#  'he',
#  'e',
#  'the',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'the',
#  'e',
#  'in',
#  'e',
#  'in',
#  'e',
#  'ere',
#  'e',
#  'rock',
#  'rea',
#  'ane',
#  'st',
#  'ee',
#  'ere',
#  'e',
#  'iee',
#  'tee',
#  'e',
#  'meni',
#  'e',
#  'siver',
#  'our',
#  'e',
#  'in',
#  'e',
#  's',
#  'ae',
#  'ee',
#  'ine',
#  'six',
#  'eere',
#  'e',
#  'ing',
#  't',
#  'm',
#  'europe',
#  'n',
#  'e',
#  'an',
#  'the',
#  'case',
#  'ee',
#  'tee',
#  'e',
#  'e',
#  'the',
#  'e',
#  'in',
#  'e',
#  'in',
#  'ee',
#  'years',
#  'e',
#  'e',
#  'y',
#  'ur',
#  'and',
#  't',
#  'e',
#  'ne',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'iee',
#  'tee',
#  'e',
#  's',
#  'ae',
#  'e',
#  'the',
#  'e',
#  'on',
#  'e',
#  'taree',
#  'tne',
#  'ee',
#  'ly',
#  'te',
#  'eea',
#  'ly',
#  'ae',
#  'e',
#  'ing',
#  't',
#  'and',
#  'te',
#  'e',
#  'ing',
#  't',
#  'e',
#  'in',
#  'e',
#  'e',
#  'in',
#  'e',
#  'ion',
#  'ee',
#  'toe',
#  'te',
#  'f',
#  'ue',
#  'in',
#  'e',
#  'e',
#  'perte',
#  'e',
#  's',
#  'ae',
#  'e',
#  'on',
#  'se',
#  'on',
#  'e',
#  'ine',
#  'tee',
#  'he',
#  'e',
#  'e',
#  'ere',
#  'e',
#  'ne',
#  'tee',
#  'ine',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'ale',
#  'e',
#  'ment',
#  'iee',
#  'tee',
#  'e',
#  'co',
#  'te',
#  'ee',
#  'be',
#  'our',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'iee',
#  'tee',
#  'iee',
#  'tee',
#  'ale',
#  'iee',
#  'tee',
#  'e',
#  'joct',
#  'e',
#  'ne',
#  'i',
#  'e',
#  'an',
#  'tee',
#  'toe',
#  'e',
#  'co',
#  'te',
#  'iee',
#  'tee',
#  'eee',
#  'al',
#  'ing',
#  't',
#  'e',
#  'an',
#  'e',
#  'and',
#  'a',
#  'ing',
#  'e',
#  'joct',
#  'e',
#  'perte',
#  'e',
#  'ment',
#  'e',
#  's',
#  'e',
#  'oe',
#  'the',
#  'bert',
#  'e',
#  'aest',
#  'the',
#  'bee',
#  'e',
#  'the',
#  'ee',
#  'tee',
#  'he',
#  'o',
#  'k',
#  'e',
#  'the',
#  'e',
#  'e',
#  'e',
#  'on',
#  'tee',
#  'mase',
#  'e',
#  'on',
#  't',
#  'e',
#  'base',
#  'ine',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'bet',
#  'eee',
#  'to',
#  'e',
#  'men',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'eading',
#  'the',
#  'e',
#  'e',
#  'an',
#  'e',
#  'an',
#  'e',
#  'ee',
#  'toe',
#  'e',
#  'in',
#  'requered',
#  'of',
#  'e',
#  'e',
#  's',
#  'at',
#  'our',
#  'e',
#  'in',
#  'e',
#  'e',
#  'on',
#  'e',
#  'mene',
#  'and',
#  't',
#  'ee',
#  'toe',
#  'e',
#  'the',
#  'e',
#  's',
#  'ae',
#  'e',
#  'ne',
#  'five',
#  'ee',
#  'e',
#  'ine',
#  'tee',
#  'e',
#  'an',
#  'e',
#  'two',
#  'ero',
#  'zero',
#  'zero',
#  'e',
#  'ero',
#  'ale',
#  'e',
#  'ne',
#  'tee',
#  'e',
#  'an',
#  'e',
#  'the',
#  'e',
#  'in',
#  'e',
#  'e',
#  'ere',
#  'e',
#  'ne',
#  'tee',
#  'e',
#  'iee',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'co',
#  'te',
#  'e',
#  'an',
#  'he',
#  'e',
#  'ce',
#  'te',
#  'e',
#  'an',
#  'e',
#  'on',
#  'e',
#  'on',
#  'e',
#  's',
#  'ae',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'and',
#  'te',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'e',
#  'ere',
#  'ing',
#  't',
#  'e',
#  's',
#  'ae',
#  'iee',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'at',
#  'the',
#  'he',
#  'e',
#  'ine',
#  'tee',
#  'e',
#  'tero',
#  'e',
#  'ee',
#  'ine',
#  'five',
#  'ee',
#  'ee',
#  'teo',
#  'ero',
#  'zero',
#  'zero',
#  'er',
#  'e',
#  'ne',
#  'iree',
#  'tee',
#  'e',
#  's',
#  'ae',
#  'e',
#  'ine',
#  'tee',
#  'e',
#  'meni',
#  'en',
#  'one',
#  'nine',
#  'ei',
#  'e',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'ine',
#  'tee',
#  'ine',
#  'tee',
#  'one',
#  'ine',
#  'six',
#  'zero',
#  's',
#  'ro',
#  'e',
#  'co',
#  'e',
#  'ere',
#  'e',
#  'in',
#  'ee',
#  'and',
#  'to',
#  'e',
#  'e',
#  'an',
#  'ale',
#  'he',
#  'e',
#  'e',
#  'on',
#  'e',
#  'ine',
#  'tne',
#  'seco',
#  'de',
#  'ine',
#  'tee',
#  'e',
#  'an',
#  'o',
#  'k',
#  'our',
#  'e',
#  'an',
#  'e',
#  'on',
#  'and',
#  'te',
#  'e',
#  'in',
#  'e',
#  'an',
#  'ing',
#  't',
#  'he',
#  'e',
#  't',
#  'e',
#  'an',
#  'e',
#  's',
#  'ae',
#  'seecial',
#  'e',
#  'an',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'he',
#  'e',
#  'ment',
#  'e',
#  'ing',
#  't',
#  'e',
#  'in',
#  'e',
#  'e',
#  'an',
#  'e',
#  'the',
#  'e',
#  'ere',
#  'e',
#  'jorn',
#  'on',
#  'e',
#  'e',
#  'he',
#  'e',
#  ...]
