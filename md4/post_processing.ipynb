# %%
import pickle
from multiprocessing import Pool

with open("/root/md4/data_dir/text8/text8_vocab.pkl", "rb") as f:
    vocab = pickle.load(f)

# %%
def post_process(texts):
    concated = " ".join(texts)
    generated_words = concated.split()
    s = 0
    for word in generated_words:
        if word in vocab:
            s += 1
    return s / len(generated_words)

# %%
with open("/root/md4/data_dir/text8/informed_corrector_generations_256.pkl", "rb") as f:
    results_dict = pickle.load(f)
with Pool(64) as p:
    acc_dict = dict(
        zip(results_dict.keys(), p.map(post_process, results_dict.values()))
    )

# %%
with open(
    "/root/md4/data_dir/text8/informed_corrector_generations_256_acc.pkl", "wb"
) as f:
    pickle.dump(acc_dict, f)

# %%
meta_dict = {}
timestep_list = [16, 32, 64, 128, 256]
for timesteps in timestep_list:
    with open(
        f"/root/md4/data_dir/text8/informed_corrector_generations_{timesteps}_acc.pkl",
        "rb",
    ) as f:
        results_dict = pickle.load(f)
    meta_dict[timesteps] = results_dict

# %%
for timesteps in timestep_list:
    meta_dict[timesteps] = max(meta_dict[timesteps].values())

# %%
with open(
    "/root/md4/data_dir/text8/informed_corrector_generations_acc_max.pkl", "wb"
) as f:
    pickle.dump(meta_dict, f)

# %%
with open("/root/md4/data_dir/text8/uninformed_corrector_generations.pkl", "rb") as f:
    results_dict = pickle.load(f)

with Pool(64) as p:
    acc_dict = dict(
        zip(results_dict.keys(), p.map(post_process, results_dict.values()))
    )

with open(
    "/root/md4/data_dir/text8/uninformed_corrector_generations_acc.pkl", "wb"
) as f:
    pickle.dump(acc_dict, f)

# %%
timestep_list = [16, 32, 64, 128, 256]

# %%
new_dict = {}
for timesteps in timestep_list:
    new_dict[timesteps] = max(
        [acc_dict[timesteps, step_size] for step_size in [0.5, 1.0, 2.0, 4.0]]
    )
with open(
    "/root/md4/data_dir/text8/uninformed_corrector_generations_acc_max.pkl", "wb"
) as f:
    pickle.dump(new_dict, f)

# %%
with open("/root/md4/data_dir/text8/maskgit_generations.pkl", "rb") as f:
    results_dict = pickle.load(f)

with Pool(64) as p:
    acc_dict = dict(
        zip(results_dict.keys(), p.map(post_process, results_dict.values()))
    )

with open("/root/md4/data_dir/text8/maskgit_generations_acc.pkl", "wb") as f:
    pickle.dump(acc_dict, f)

# %%
timestep_list = [16, 32, 64, 128, 256]
for timesteps in timestep_list:
    new_dict[timesteps] = max(
        [
            acc_dict[timesteps, tem]
            for tem in [0.5, 1.0, 2.0, 4.0, 8.0, 10.0, 12.0, 16.0, 20.0, 40.0]
        ]
    )
with open("/root/md4/data_dir/text8/maskgit_generations_acc_max.pkl", "wb") as f:
    pickle.dump(new_dict, f)

# %%
# get all four acc_max
import pickle

meta_results_dict = {}
with open(
    "/home/fengchen/md4/data_dir/text8/maskgit_generations_acc_max.pkl", "rb"
) as f:
    meta_results_dict["maskgit"] = pickle.load(f)
with open(
    "/home/fengchen/md4/data_dir/text8/informed_corrector_generations_acc_max.pkl", "rb"
) as f:
    meta_results_dict["informed_corrector"] = pickle.load(f)
with open(
    "/home/fengchen/md4/data_dir/text8/uninformed_corrector_generations_acc_max.pkl",
    "rb",
) as f:
    meta_results_dict["uninformed_corrector"] = pickle.load(f)
with open("/home/fengchen/md4/data_dir/text8/baseline_acc.pkl", "rb") as f:
    meta_results_dict["baseline"] = pickle.load(f)

# %%
from matplotlib import pyplot as plt
import numpy as np

timestep_list = [16, 32, 64, 128, 256]
for key, value in meta_results_dict.items():
    plt.plot(
        timestep_list,
        1 - np.array([value[timestep] for timestep in timestep_list]),
        label=key,
    )
plt.legend()
plt.ylabel("Error Rate")
plt.xlabel("NFEs")
plt.grid()

# %%
import math
import seaborn as sns

# palette = sns.color_palette("tab10", n_colors=10)
palette = sns.color_palette("hls", n_colors=10)

# The parameters are kind of confusing here
method_mapping = {
    ("gibbs", 0, "gibbs"): "Ancestral (no corrector)",
    ("gibbs", 1, "gibbs"): "Ancestral (informed corrector)",
    ("euler", 1, "forward_backward"): "Ancestral (uninformed corrector)",
    ("maskgit", 0, "none"): "MaskGIT (no corrector)",
}

color_mapping = {
    ("gibbs", 0, "gibbs"): "grey",
    ("gibbs", 1, "gibbs"): palette[6],
    ("euler", 1, "forward_backward"): palette[1],
    ("maskgit", 0, "none"): palette[0],
}


# Apply mapping function to correctly label methods
def get_corrected_method_label(row):
    key = (row["method"], row["num_cstep"], row["corrector"])
    return method_mapping.get(key, "Other")


# Plot with all four groups
fig = plt.figure(figsize=(8, 6))

# for label, group in corrected_filtered_df.groupby("method_label"):
#     group = group.sort_values("NFE")
#     plt.plot(group["NFE"], group["fid"], marker="o", linestyle="-",
#              label=label, linewidth=2,
#              color=color_mapping.get(tuple(group[["method", "num_cstep", "corrector"]].iloc[0])))
label_mapping = {
    "informed_corrector": "Ancestral (informed corrector)",
    "uninformed_corrector": "Ancestral (uninformed corrector)",
    "baseline": "Ancestral (no corrector)",
    "maskgit": "MaskGIT (no corrector)",
}

for ii, key in enumerate(
    ["informed_corrector", "uninformed_corrector", "maskgit", "baseline"]
):
    plt.plot(
        timestep_list,
        100
        - 100
        * np.array([meta_results_dict[key][timestep] for timestep in timestep_list]),
        label=label_mapping[key],
        marker="o",
        linestyle="-",
        linewidth=2,
        color=[palette[6], palette[1], palette[0], "grey"][ii],
    )

plt.xlabel("Number of Function Evaluations (NFEs)", fontsize=16)
plt.ylabel("Error Rate (%)", fontsize=16)
# plt.title("Comparison of Diffusion Sampling Methods")
# plt.legend()

# Define the desired order of legend entries


# Apply the ordered legend
plt.legend(fontsize=16)


plt.xscale("log")
plt.yticks(fontsize=16)
plt.xticks([16, 32, 64, 128, 256], fontsize=16)
plt.gca().get_xaxis().set_major_formatter(ticker.ScalarFormatter())
plt.minorticks_off()
plt.grid(True)
plt.show()

fig.savefig("sampling_methods_text8.pdf", bbox_inches="tight")

# %%
from matplotlib import pyplot as plt
import numpy as np
from matplotlib import ticker

# Define the mapping between keys and descriptive labels
label_mapping = {
    "informed_corrector": "Ancestral (informed corrector)",
    "uninformed_corrector": "Ancestral (uninformed corrector)",
    "baseline": "Ancestral (no corrector)",
    "maskgit": "MaskGIT (no corrector)",
}

timestep_list = [16, 32, 64, 128, 256]
for key, value in meta_results_dict.items():
    plt.plot(
        timestep_list,
        1 - np.array([value[timestep] for timestep in timestep_list]),
        label=label_mapping[key],
    )
plt.legend()
plt.ylabel("Error Rate")
plt.xlabel("NFEs")
plt.grid()

# %%
with open(
    "/root/md4/data_dir/text8/informed_corrector_generations_32_acc.pkl", "rb"
) as f:
    results_dict = pickle.load(f)

# %%
results_dict
# Out:
# {(1, 0.1): 0.904065390406539,
#  (1, 1.0): 0.8800309597523219,
#  (1, 2.0): 0.8369433897134967,
#  (1, 10.0): 0.772189863513866,
#  (1, 1000.0): 0.7615160856162897,
#  (2, 0.1): 0.9350966690958975,
#  (2, 1.0): 0.9271560025679435,
#  (2, 2.0): 0.8891309920533197,
#  (2, 10.0): 0.798390237569778,
#  (2, 1000.0): 0.7821040322231365,
#  (4, 0.1): 0.9580700506339708,
#  (4, 1.0): 0.7615160856162897,
#  (4, 2.0): 0.9347062853228293,
#  (4, 10.0): 0.813671587514611,
#  (4, 1000.0): 0.7821040322231365,
#  (8, 0.1): 0.9566152597402597,
#  (8, 1.0): 0.9532112023583912,
#  (8, 2.0): 0.9461368277739959,
#  (8, 10.0): 0.8407232027550581,
#  (8, 1000.0): 0.8010197411426331,
#  (16, 0.1): 0.9349056230461794,
#  (16, 1.0): 0.933620159803319,
#  (16, 2.0): 0.9360852197070573,
#  (16, 10.0): 0.8419837537409149,
#  (16, 1000.0): 0.7876209398756047}

# %%
with open(
    "/root/md4/data_dir/text8/uninformed_corrector_generations_acc.pkl", "rb"
) as f:
    results_dict = pickle.load(f)

x_list = []
y_list = []
value_list = []
for key, value in results_dict.items():
    x_list.append(key[0])
    y_list.append(key[1])
    value_list.append(value)

# plot those with the sample x values and plot curves with different y values
x_list = np.array(x_list)
y_list = np.array(y_list)
value_list = np.array(value_list)

for x in set(x_list):
    plt.plot(y_list[x_list == x], 1 - value_list[x_list == x], label=f"{x}")
plt.legend(title="Timesteps")
plt.xlabel("Step Size")
plt.ylabel("Error Rate")
plt.grid()
plt.show()

# %%
with open("/root/md4/data_dir/text8/uninformed_corrector_generations.pkl", "rb") as f:
    results_dict = pickle.load(f)

# %%
texts = results_dict[16, 0.5]

# %%
concated = " ".join(texts)
generated_words = concated.split()
s = 0
for word in generated_words:
    if word in vocab:
        s += len(word) + 1
s / len(concated)
# Out:
# 0.5581952075876063

# %%
"te" in vocab
# Out:
# True

# %%
concated
# Out:
# '                            our                        e co te                    e s ae          ee  ly ae                        he                                    ee  ly ae                           iee tee                                                                                              e  on                      e  an                                                                                                                               e  an                    and te           e  in                                                                                                                                                 iee tee                                                                   e the               e ment     r men                                                       iee of the                                                               he                   e  on                                                                          our    e  in                 e t                          our                                                             e  ere                                  iee tee                                                            our                         he                                                                                                                                          e the                     he                                                                                                                          e  in                                                  e ing t                                                               ee  an  ingh                     e  in  e                                                     ine tee                        ing t               e  ine tee                                                                                                            he                                             e  wo       e                                       he                                     e  an                                                                                     e  iee tee                                                                                                            e  external  i  s                                                                               e  in  e e  on           e  our                                                                                  e s  ee and to                                                                                                                   e  an    e  an  an                         iee tee                                                                                                                                                                                                                                                                    e  on           e s ae                                                                          and te                                                                                                                                                              o k                  e  in  e                       e be                                         ine tee                                                                                                                                                                                                        and te                                                                                                                                                   iee tee                                          ine tee                                                                  e s ae                                          ing t               e  an                                                                                                                                                                    ...

# %%
generated_words
# Out:
# ['our',
#  'e',
#  'co',
#  'te',
#  'e',
#  's',
#  'ae',
#  'ee',
#  'ly',
#  'ae',
#  'he',
#  'ee',
#  'ly',
#  'ae',
#  'iee',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'an',
#  'e',
#  'an',
#  'and',
#  'te',
#  'e',
#  'in',
#  'iee',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'ment',
#  'r',
#  'men',
#  'iee',
#  'of',
#  'the',
#  'he',
#  'e',
#  'on',
#  'our',
#  'e',
#  'in',
#  'e',
#  't',
#  'our',
#  'e',
#  'ere',
#  'iee',
#  'tee',
#  'our',
#  'he',
#  'e',
#  'the',
#  'he',
#  'e',
#  'in',
#  'e',
#  'ing',
#  't',
#  'ee',
#  'an',
#  'ingh',
#  'e',
#  'in',
#  'e',
#  'ine',
#  'tee',
#  'ing',
#  't',
#  'e',
#  'ine',
#  'tee',
#  'he',
#  'e',
#  'wo',
#  'e',
#  'he',
#  'e',
#  'an',
#  'e',
#  'iee',
#  'tee',
#  'e',
#  'external',
#  'i',
#  's',
#  'e',
#  'in',
#  'e',
#  'e',
#  'on',
#  'e',
#  'our',
#  'e',
#  's',
#  'ee',
#  'and',
#  'to',
#  'e',
#  'an',
#  'e',
#  'an',
#  'an',
#  'iee',
#  'tee',
#  'e',
#  'on',
#  'e',
#  's',
#  'ae',
#  'and',
#  'te',
#  'o',
#  'k',
#  'e',
#  'in',
#  'e',
#  'e',
#  'be',
#  'ine',
#  'tee',
#  'and',
#  'te',
#  'iee',
#  'tee',
#  'ine',
#  'tee',
#  'e',
#  's',
#  'ae',
#  'ing',
#  't',
#  'e',
#  'an',
#  'he',
#  'e',
#  's',
#  'ae',
#  'iee',
#  'tee',
#  'e',
#  'an',
#  'o',
#  'k',
#  'and',
#  'at',
#  'our',
#  'e',
#  'the',
#  'e',
#  'on',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'e',
#  'in',
#  'e',
#  'he',
#  'ie',
#  'our',
#  'e',
#  'in',
#  'iee',
#  'tee',
#  'our',
#  'ine',
#  'tee',
#  'our',
#  'e',
#  'wo',
#  'iee',
#  'tee',
#  'the',
#  'mas',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'and',
#  'te',
#  'he',
#  'e',
#  'ing',
#  't',
#  'o',
#  'in',
#  'e',
#  'ine',
#  'tee',
#  'e',
#  'the',
#  'ad',
#  'n',
#  'e',
#  'on',
#  'ne',
#  'in',
#  'e',
#  't',
#  'ine',
#  'tee',
#  'ine',
#  'tee',
#  'ine',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'e',
#  'ere',
#  'iee',
#  'tee',
#  'and',
#  'te',
#  'e',
#  'in',
#  'e',
#  'an',
#  'e',
#  'co',
#  'oee',
#  'in',
#  'e',
#  'e',
#  'in',
#  'and',
#  'te',
#  'al',
#  'e',
#  'in',
#  'e',
#  'e',
#  'on',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'e',
#  'on',
#  'e',
#  'an',
#  'e',
#  'joct',
#  'e',
#  'the',
#  'e',
#  'e',
#  'e',
#  'an',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'iee',
#  'tee',
#  'iee',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'e',
#  'ere',
#  'our',
#  'a',
#  'ke',
#  'an',
#  'e',
#  'the',
#  'ee',
#  'e',
#  'ment',
#  'iee',
#  'tee',
#  'e',
#  'be',
#  'e',
#  'in',
#  'e',
#  'an',
#  'ine',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'ine',
#  'tee',
#  'he',
#  'ie',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'e',
#  'on',
#  'iee',
#  'tee',
#  'iee',
#  'tee',
#  'e',
#  'ee',
#  'f',
#  're',
#  'e',
#  'an',
#  'equent',
#  'e',
#  'five',
#  'e',
#  'e',
#  'the',
#  'ee',
#  'e',
#  'an',
#  'e',
#  'perte',
#  'e',
#  's',
#  'ae',
#  'e',
#  's',
#  'ae',
#  'ale',
#  'e',
#  'on',
#  'e',
#  'in',
#  'ee',
#  'ine',
#  'tiee',
#  'iee',
#  'tee',
#  'e',
#  's',
#  'ae',
#  'e',
#  'an',
#  'e',
#  'the',
#  'e',
#  'e',
#  'an',
#  'e',
#  'ine',
#  'zero',
#  'zero',
#  'zero',
#  'e',
#  'iee',
#  'tee',
#  'an',
#  'e',
#  'ment',
#  'e',
#  'perte',
#  'he',
#  'oe',
#  'y',
#  'ung',
#  'ing',
#  't',
#  'e',
#  'ch',
#  'an',
#  'e',
#  'an',
#  'e',
#  's',
#  'ae',
#  'e',
#  'the',
#  'e',
#  'co',
#  'te',
#  'e',
#  'on',
#  'e',
#  'ere',
#  'an',
#  'e',
#  'ine',
#  'te',
#  're',
#  'e',
#  'ee',
#  'tee',
#  'ee',
#  'ly',
#  'ae',
#  'and',
#  'te',
#  'one',
#  'eight',
#  'sir',
#  'and',
#  'tion',
#  'ale',
#  'e',
#  'an',
#  'e',
#  'joct',
#  'e',
#  'enght',
#  'e',
#  's',
#  'e',
#  'ee',
#  'ly',
#  'ae',
#  'our',
#  'e',
#  'ere',
#  'and',
#  'te',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'e',
#  'an',
#  're',
#  'ne',
#  'tee',
#  'our',
#  'ee',
#  'ly',
#  'ae',
#  'he',
#  'ad',
#  'n',
#  'e',
#  'the',
#  'e',
#  'ane',
#  'ne',
#  'toe',
#  'e',
#  'an',
#  'ee',
#  'be',
#  'e',
#  'an',
#  'e',
#  'ment',
#  'and',
#  'te',
#  'e',
#  'an',
#  'e',
#  'ment',
#  'e',
#  'in',
#  'e',
#  'on',
#  'e',
#  'ine',
#  'teee',
#  'iee',
#  'tee',
#  'e',
#  'ment',
#  'e',
#  'perte',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'our',
#  'ale',
#  'e',
#  'in',
#  'e',
#  'e',
#  'ment',
#  'os',
#  'toe',
#  'i',
#  'e',
#  's',
#  'ane',
#  'tee',
#  'e',
#  'th',
#  's',
#  'ae',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'ate',
#  'nal',
#  'e',
#  'ment',
#  'e',
#  'pert',
#  'ere',
#  'e',
#  'ere',
#  'e',
#  'one',
#  'ine',
#  'eight',
#  'e',
#  'an',
#  'e',
#  'ine',
#  'tee',
#  'he',
#  'e',
#  'mene',
#  'ane',
#  'tee',
#  'he',
#  'e',
#  'the',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'the',
#  'e',
#  'in',
#  'e',
#  'in',
#  'e',
#  'ere',
#  'e',
#  'rock',
#  'rea',
#  'ane',
#  'st',
#  'ee',
#  'ere',
#  'e',
#  'iee',
#  'tee',
#  'e',
#  'meni',
#  'e',
#  'siver',
#  'our',
#  'e',
#  'in',
#  'e',
#  's',
#  'ae',
#  'ee',
#  'ine',
#  'six',
#  'eere',
#  'e',
#  'ing',
#  't',
#  'm',
#  'europe',
#  'n',
#  'e',
#  'an',
#  'the',
#  'case',
#  'ee',
#  'tee',
#  'e',
#  'e',
#  'the',
#  'e',
#  'in',
#  'e',
#  'in',
#  'ee',
#  'years',
#  'e',
#  'e',
#  'y',
#  'ur',
#  'and',
#  't',
#  'e',
#  'ne',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'iee',
#  'tee',
#  'e',
#  's',
#  'ae',
#  'e',
#  'the',
#  'e',
#  'on',
#  'e',
#  'taree',
#  'tne',
#  'ee',
#  'ly',
#  'te',
#  'eea',
#  'ly',
#  'ae',
#  'e',
#  'ing',
#  't',
#  'and',
#  'te',
#  'e',
#  'ing',
#  't',
#  'e',
#  'in',
#  'e',
#  'e',
#  'in',
#  'e',
#  'ion',
#  'ee',
#  'toe',
#  'te',
#  'f',
#  'ue',
#  'in',
#  'e',
#  'e',
#  'perte',
#  'e',
#  's',
#  'ae',
#  'e',
#  'on',
#  'se',
#  'on',
#  'e',
#  'ine',
#  'tee',
#  'he',
#  'e',
#  'e',
#  'ere',
#  'e',
#  'ne',
#  'tee',
#  'ine',
#  'tee',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'ale',
#  'e',
#  'ment',
#  'iee',
#  'tee',
#  'e',
#  'co',
#  'te',
#  'ee',
#  'be',
#  'our',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'iee',
#  'tee',
#  'iee',
#  'tee',
#  'ale',
#  'iee',
#  'tee',
#  'e',
#  'joct',
#  'e',
#  'ne',
#  'i',
#  'e',
#  'an',
#  'tee',
#  'toe',
#  'e',
#  'co',
#  'te',
#  'iee',
#  'tee',
#  'eee',
#  'al',
#  'ing',
#  't',
#  'e',
#  'an',
#  'e',
#  'and',
#  'a',
#  'ing',
#  'e',
#  'joct',
#  'e',
#  'perte',
#  'e',
#  'ment',
#  'e',
#  's',
#  'e',
#  'oe',
#  'the',
#  'bert',
#  'e',
#  'aest',
#  'the',
#  'bee',
#  'e',
#  'the',
#  'ee',
#  'tee',
#  'he',
#  'o',
#  'k',
#  'e',
#  'the',
#  'e',
#  'e',
#  'e',
#  'on',
#  'tee',
#  'mase',
#  'e',
#  'on',
#  't',
#  'e',
#  'base',
#  'ine',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'bet',
#  'eee',
#  'to',
#  'e',
#  'men',
#  'e',
#  'the',
#  'e',
#  'ee',
#  'eading',
#  'the',
#  'e',
#  'e',
#  'an',
#  'e',
#  'an',
#  'e',
#  'ee',
#  'toe',
#  'e',
#  'in',
#  'requered',
#  'of',
#  'e',
#  'e',
#  's',
#  'at',
#  'our',
#  'e',
#  'in',
#  'e',
#  'e',
#  'on',
#  'e',
#  'mene',
#  'and',
#  't',
#  'ee',
#  'toe',
#  'e',
#  'the',
#  'e',
#  's',
#  'ae',
#  'e',
#  'ne',
#  'five',
#  'ee',
#  'e',
#  'ine',
#  'tee',
#  'e',
#  'an',
#  'e',
#  'two',
#  'ero',
#  'zero',
#  'zero',
#  'e',
#  'ero',
#  'ale',
#  'e',
#  'ne',
#  'tee',
#  'e',
#  'an',
#  'e',
#  'the',
#  'e',
#  'in',
#  'e',
#  'e',
#  'ere',
#  'e',
#  'ne',
#  'tee',
#  'e',
#  'iee',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'co',
#  'te',
#  'e',
#  'an',
#  'he',
#  'e',
#  'ce',
#  'te',
#  'e',
#  'an',
#  'e',
#  'on',
#  'e',
#  'on',
#  'e',
#  's',
#  'ae',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'and',
#  'te',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'e',
#  'ere',
#  'ing',
#  't',
#  'e',
#  's',
#  'ae',
#  'iee',
#  'tee',
#  'e',
#  'on',
#  'e',
#  'at',
#  'the',
#  'he',
#  'e',
#  'ine',
#  'tee',
#  'e',
#  'tero',
#  'e',
#  'ee',
#  'ine',
#  'five',
#  'ee',
#  'ee',
#  'teo',
#  'ero',
#  'zero',
#  'zero',
#  'er',
#  'e',
#  'ne',
#  'iree',
#  'tee',
#  'e',
#  's',
#  'ae',
#  'e',
#  'ine',
#  'tee',
#  'e',
#  'meni',
#  'en',
#  'one',
#  'nine',
#  'ei',
#  'e',
#  'e',
#  'an',
#  'iee',
#  'tee',
#  'ine',
#  'tee',
#  'ine',
#  'tee',
#  'one',
#  'ine',
#  'six',
#  'zero',
#  's',
#  'ro',
#  'e',
#  'co',
#  'e',
#  'ere',
#  'e',
#  'in',
#  'ee',
#  'and',
#  'to',
#  'e',
#  'e',
#  'an',
#  'ale',
#  'he',
#  'e',
#  'e',
#  'on',
#  'e',
#  'ine',
#  'tne',
#  'seco',
#  'de',
#  'ine',
#  'tee',
#  'e',
#  'an',
#  'o',
#  'k',
#  'our',
#  'e',
#  'an',
#  'e',
#  'on',
#  'and',
#  'te',
#  'e',
#  'in',
#  'e',
#  'an',
#  'ing',
#  't',
#  'he',
#  'e',
#  't',
#  'e',
#  'an',
#  'e',
#  's',
#  'ae',
#  'seecial',
#  'e',
#  'an',
#  'e',
#  'an',
#  'e',
#  'in',
#  'e',
#  'he',
#  'e',
#  'ment',
#  'e',
#  'ing',
#  't',
#  'e',
#  'in',
#  'e',
#  'e',
#  'an',
#  'e',
#  'the',
#  'e',
#  'ere',
#  'e',
#  'jorn',
#  'on',
#  'e',
#  'e',
#  'he',
#  'e',
#  ...]
